# %% [markdown]
# # Timestep-Flexible S5 Reconstruction
#
# Minimal Colab notebook for training the timestep-flexible Brain2Text24 S5 decoder and plotting `20 ms` / `40 ms` validation diagnostics.

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
import subprocess
import sys
from pathlib import Path

REPO_DIR = Path('/content/utah-ssl')
REPO_URL = 'https://github.com/ethan-read/utah-ssl.git'

if not REPO_DIR.exists():
    # !git clone {REPO_URL} {REPO_DIR}
else:
    # %cd {REPO_DIR}
    # !git pull --ff-only || true

# %cd {REPO_DIR}
# !pip install -q torch pandas matplotlib

RAW_CACHE_ROOT = Path('/content/drive/MyDrive/utah_ssl/data/cache_v1')
SMOOTHED_CACHE_ROOT = Path('/content/drive/MyDrive/utah_ssl/data/cache_v1_smoothed_sigma2p0')
TRIM_SCRIPT = REPO_DIR / 'utah_ssl' / 'scripts' / 'trim_area6v_cache.py'
OUTPUT_ROOT = Path('/content/drive/MyDrive/utah_ssl/outputs/timestep_flexible_ssm')
EXPERIMENTS_DIR = REPO_DIR / 'experiments'
PYTHONPATH = str(EXPERIMENTS_DIR)
os.environ['PYTHONPATH'] = PYTHONPATH
if PYTHONPATH not in sys.path:
    sys.path.insert(0, PYTHONPATH)

for cache_root in (RAW_CACHE_ROOT, SMOOTHED_CACHE_ROOT):
    dataset_root = cache_root / 'brain2text24'
    if dataset_root.exists():
        subprocess.run(
            ['python', str(TRIM_SCRIPT), '--cache-root', str(cache_root)],
            check=True,
            cwd=str(REPO_DIR),
        )

print('RAW_CACHE_ROOT:', RAW_CACHE_ROOT)
print('SMOOTHED_CACHE_ROOT:', SMOOTHED_CACHE_ROOT)
print('OUTPUT_ROOT:', OUTPUT_ROOT)
# Out:
# Mounted at /content/drive
# Cloning into '/content/utah-ssl'...
# remote: Enumerating objects: 1133, done.
# remote: Counting objects: 100% (442/442), done.
# remote: Compressing objects: 100% (256/256), done.
# remote: Total 1133 (delta 212), reused 344 (delta 141), pack-reused 691 (from 1)
# Receiving objects: 100% (1133/1133), 4.25 MiB | 19.80 MiB/s, done.
# Resolving deltas: 100% (543/543), done.
# /content/utah-ssl
# RAW_CACHE_ROOT: /content/drive/MyDrive/utah_ssl/data/cache_v1
# SMOOTHED_CACHE_ROOT: /content/drive/MyDrive/utah_ssl/data/cache_v1_smoothed_sigma2p0
# OUTPUT_ROOT: /content/drive/MyDrive/utah_ssl/outputs/timestep_flexible_ssm

# %%
from pathlib import Path

RUN_NAME = 'timestep_flexible_s5_tx_only_colab'
DATASET = 'brain2text24'
FEATURE_MODE = 'tx_only'
CACHE_ROOT = RAW_CACHE_ROOT
MAX_STEPS = 10000
BATCH_SIZE = 64
LEARNING_RATE = 1e-2
MIN_LEARNING_RATE = 1e-4
ADAM_EPSILON = 1e-1
SESSION_ADAPTER = True
NORMALIZATION_MODE = 'global'
TRAIN_BIN_SIZE_MS = 20
EVAL_BIN_SIZES_MS = (20, 40)
PATCH_SIZE_MS = 280
PATCH_STRIDE_MS = 80
RESUME_LATEST = False

RUN_DIR = OUTPUT_ROOT / RUN_NAME
RUN_DIR
# Out:
# PosixPath('/content/drive/MyDrive/utah_ssl/outputs/timestep_flexible_ssm/timestep_flexible_s5_tx_only_colab')

# %%
import json
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

RUN_DIR = OUTPUT_ROOT / RUN_NAME
progress_path = RUN_DIR / 'progress.jsonl'
summary_path = RUN_DIR / 'summary.json'

if not progress_path.exists():
    print(f'No progress log yet at: {progress_path}')
    print('Run the training cell first, then come back here to preview the curves.')
else:
    progress = [json.loads(line) for line in progress_path.read_text().splitlines() if line.strip()]
    df = pd.DataFrame(progress)

    train_df = df[df.get('event').eq('timestep_flexible_train_report')] if 'event' in df.columns else pd.DataFrame()
    val_df = df[df.get('event').eq('timestep_flexible_val_report')] if 'event' in df.columns else pd.DataFrame()

    fig, axes = plt.subplots(1, 2, figsize=(14, 4))

    if not train_df.empty and 'step' in train_df and 'train_ctc_bpphone' in train_df:
        axes[0].plot(train_df['step'], train_df['train_ctc_bpphone'], label='train CTC')
    if not val_df.empty:
        if 'val_20ms_ctc_bpphone' in val_df:
            axes[0].plot(val_df['step'], val_df['val_20ms_ctc_bpphone'], marker='o', label='val 20 ms CTC')
        if 'val_40ms_ctc_bpphone' in val_df:
            axes[0].plot(val_df['step'], val_df['val_40ms_ctc_bpphone'], marker='o', label='val 40 ms CTC')
    axes[0].set_title('Timestep-Flexible S5 CTC')
    axes[0].set_xlabel('step')
    axes[0].set_ylabel('bits / phoneme')
    axes[0].legend()

    if not val_df.empty:
        if 'val_20ms_phoneme_error_rate' in val_df:
            axes[1].plot(val_df['step'], val_df['val_20ms_phoneme_error_rate'], marker='o', label='val 20 ms PER')
        if 'val_40ms_phoneme_error_rate' in val_df:
            axes[1].plot(val_df['step'], val_df['val_40ms_phoneme_error_rate'], marker='o', label='val 40 ms PER')
    axes[1].set_title('Timestep-Flexible S5 PER')
    axes[1].set_xlabel('step')
    axes[1].set_ylabel('PER')
    axes[1].legend()

    plt.tight_layout()
    plt.show()

    if summary_path.exists():
        summary = json.loads(summary_path.read_text())
        print(json.dumps(summary.get('metrics', {}), indent=2))
# Out:
# {
#   "selection_bin_size_ms": 20,
#   "best_val_phoneme_error_rate": 0.5544730215084837,
#   "metrics_by_bin_ms": {
#     "20": {
#       "val_ctc_bpphone": 2.8996564430344858,
#       "val_phoneme_error_rate": 0.5560830615530694,
#       "active_bin_size_ms": 20,
#       "dt_scale": 1.0,
#       "active_patch_size_bins": 14,
#       "active_patch_stride_bins": 4,
#       "edit_diagnostics": {
#         "insertions": 158,
#         "deletions": 8759,
#         "substitutions": 4553
#       },
#       "collapse_diagnostics": {
#         "total_reference_tokens": 24223,
#         "total_predicted_tokens": 15622,
#         "predicted_to_reference_token_ratio": 0.6449242455517483,
#         "blank_frame_rate": 0.45377348144202295,
#         "reference_top_ids": [
#           [
#             40,
#             5498
#           ],
#           [
#             3,
#             1621
#           ],
#           [
#             31,
#             1585
#           ],
#           [
#             23,
#             1224
#           ],
#           [
#             17,
#             1130
#           ],
#           [
#             29,
#             877
#           ],
#           [
#             28,
#             794
#           ],
#           [
#             9,
#             757
#           ],
#           [
#             21,
#             729
#           ],
#           [
#             18,
#             670
#           ]
#         ],
#         "prediction_top_ids": [
#           [
#             40,
#             5464
#           ],
#           [
#             23,
#             1161
#           ],
#           [
#             3,
#             1143
#           ],
#           [
#             31,
#             1050
#           ],
#           [
#             22,
#             511
#           ],
#           [
#             17,
#             510
#           ],
#           [
#             34,
#             495
#           ],
#           [
#             2,
#             491
#           ],
#           [
#             10,
#             434
#           ],
#           [
#             20,
#             407
#           ]
#         ]
#       }
#     },
#     "40": {
#       "val_ctc_bpphone": 2.907126830812399,
#       "val_phoneme_error_rate": 0.5569087231143954,
#       "active_bin_size_ms": 40,
#       "dt_scale": 1.0,
#       "active_patch_size_bins": 7,
#       "active_patch_stride_bins": 2,
#       "edit_diagnostics": {
#         "insertions": 141,
#         "deletions": 8861,
#         "substitutions": 4488
#       },
#       "collapse_diagnostics": {
#         "total_reference_tokens": 24223,
#         "total_predicted_tokens": 15503,
#         "predicted_to_reference_token_ratio": 0.6400115592618586,
#         "blank_frame_rate": 0.4548388612969433,
#         "reference_top_ids": [
#           [
#             40,
#             5498
#           ],
#           [
#             3,
#             1621
#           ],
#           [
#             31,
#             1585
#           ],
#           [
#             23,
#             1224
#           ],
#           [
#             17,
#             1130
#           ],
#           [
#             29,
#             877
#           ],
#           [
#             28,
#             794
#           ],
#           [
#             9,
#             757
#           ],
#           [
#             21,
#             729
#           ],
#           [
#             18,
#             670
#           ]
#         ],
#         "prediction_top_ids": [
#           [
#             40,
#             5437
#           ],
#           [
#             3,
#             1160
#           ],
#           [
#             23,
#             1160
#           ],
#           [
#             31,
#             1007
#           ],
#           [
#             22,
#             516
#           ],
#           [
#             17,
#             508
#           ],
#           [
#             34,
#             486
#           ],
#           [
#             2,
#             484
#           ],
#           [
#             10,
#             425
#           ],
#           [
#             20,
#             421
#           ]
#         ]
#       }
#     }
#   },
#   "val_20ms_ctc_bpphone": 2.8996564430344858,
#   "val_20ms_phoneme_error_rate": 0.5560830615530694,
#   "val_40ms_ctc_bpphone": 2.907126830812399,
#   "val_40ms_phoneme_error_rate": 0.5569087231143954
# }

# %% [markdown]
# ## Recompute Split Stats
#
# Run this cell when `FEATURE_MODE` changes or after trimming/rebuilding the cache. It refreshes the canonical `20 ms` competition-train global normalization stats used by the timestep-flexible trainer. The trainer derives rebinned `40 ms` stats from the train split at runtime.

# %%
import json
import subprocess

from utah_ssl.scripts.recompute_split_feature_stats import resolve_precomputed_split_stats_path

RECOMPUTE_SPLIT_STATS = True
SPLIT_STATS_SCRIPT = REPO_DIR / 'utah_ssl' / 'scripts' / 'recompute_split_feature_stats.py'

stats_output_path = resolve_precomputed_split_stats_path(
    cache_root=CACHE_ROOT,
    dataset=DATASET,
    train_split_name='competition_train',
    feature_mode=FEATURE_MODE,
    preferred_path=None,
)

trim_cmd = ['python', str(TRIM_SCRIPT), '--cache-root', str(CACHE_ROOT)]
print('Running:', ' '.join(trim_cmd))
trim_result = subprocess.run(trim_cmd, cwd=str(REPO_DIR), text=True, capture_output=True)
print('trim returncode:', trim_result.returncode)
if trim_result.stdout:
    print('\nTRIM STDOUT\n')
    print(trim_result.stdout)
if trim_result.stderr:
    print('\nTRIM STDERR\n')
    print(trim_result.stderr)
if trim_result.returncode != 0:
    raise RuntimeError('Area-6v cache trim failed before stats recompute.')

if RECOMPUTE_SPLIT_STATS:
    cmd = [
        'python', str(SPLIT_STATS_SCRIPT),
        '--cache-root', str(CACHE_ROOT),
        '--dataset', DATASET,
        '--feature-mode', FEATURE_MODE,
        '--output-path', str(stats_output_path),
        '--overwrite',
    ]
    print('Running:', ' '.join(cmd))
    result = subprocess.run(cmd, cwd=str(REPO_DIR), text=True, capture_output=True)
    print('stats returncode:', result.returncode)
    if result.stdout:
        print('\nSTATS STDOUT\n')
        print(result.stdout)
    if result.stderr:
        print('\nSTATS STDERR\n')
        print(result.stderr)
    if result.returncode != 0:
        raise RuntimeError('Split-stat recompute failed.')

print('stats_output_path:', stats_output_path)
# Out:
# Running: python /content/utah-ssl/utah_ssl/scripts/trim_area6v_cache.py --cache-root /content/drive/MyDrive/utah_ssl/data/cache_v1
# trim returncode: 0
#
# TRIM STDOUT
#
# {
#   "cache_root": "/content/drive/MyDrive/utah_ssl/data/cache_v1",
#   "dataset": "brain2text24",
#   "dry_run": false,
#   "shard_count": 44,
#   "arrays_trimmed": 0,
#   "arrays_already_trimmed": 88,
#   "manifest_rows_updated": 0
# }
#
# Running: python /content/utah-ssl/utah_ssl/scripts/recompute_split_feature_stats.py --cache-root /content/drive/MyDrive/utah_ssl/data/cache_v1 --dataset brain2text24 --feature-mode tx_only --output-path /content/drive/MyDrive/utah_ssl/data/stats/split_feature_stats/raw/brain2text24/competition_train/tx_only/global_v1.pt --overwrite
# stats returncode: 0
#
# STATS STDOUT
#
# {
#   "output_path": "/content/drive/MyDrive/utah_ssl/data/stats/split_feature_stats/raw/brain2text24/competition_train/tx_only/global_v1.pt",
#   "metadata_path": "/content/drive/MyDrive/utah_ssl/data/stats/split_feature_stats/raw/brain2text24/competition_train/tx_only/global_v1.json",
#   "metadata": {
#     "kind": "split_feature_stats",
#     "created_utc": "2026-06-17T10:32:13Z",
#     "source_cache_root": "/content/drive/MyDrive/utah_ssl/data/cache_v1",
#     "source_cache_name": "cache_v1",
#     "source_cache_variant": "raw",
#     "source_cache_signature": "9a27f1dde5d6134484063311955284b6f9d72efd7c5fc4f1e86a2a0baf3e2b03",
#     "dataset": "brain2text24",
#     "feature_mode": "tx_only",
#     "boundary_key_mode": "session",
#     "split_policy": "competition_train_test",
#     "train_split_name": "competition_train",
#     "val_split_name": "competition_test",
#     "train_examples": 8800,
#     "val_examples": 880,
#     "train_session_ids": [
#       "t12.2022.04.28",
#       "t12.2022.05.05",
#       "t12.2022.05.17",
#       "t12.2022.05.19",
#       "t12.2022.05.24",
#       "t12.2022.05.26",
#       "t12.2022.06.02",
#       "t12.2022.06.07",
#       "t12.2022.06.14",
#       "t12.2022.06.16",
#       "t12.2022.06.21",
#       "t12.2022.06.23",
#       "t12.2022.06.28",
#       "t12.2022.07.05",
#       "t12.2022.07.14",
#       "t12.2022.07.21",
#       "t12.2022.07.27",
#       "t12.2022.07.29",
#       "t12.2022.08.02",
#       "t12.2022.08.11",
#       "t12.2022.08.13",
#       "t12.2022.08.18",
#       "t12.2022.08.23",
#       "t12.2022.08.25"
#     ],
#     "val_session_ids": [
#       "t12.2022.04.28",
#       "t12.2022.05.05",
#       "t12.2022.05.17",
#       "t12.2022.05.19",
#       "t12.2022.05.24",
#       "t12.2022.05.26",
#       "t12.2022.06.02",
#       "t12.2022.06.07",
#       "t12.2022.06.14",
#       "t12.2022.06.16",
#       "t12.2022.06.21",
#       "t12.2022.06.23",
#       "t12.2022.06.28",
#       "t12.2022.07.05",
#       "t12.2022.07.14",
#       "t12.2022.07.21",
#       "t12.2022.07.27",
#       "t12.2022.07.29",
#       "t12.2022.08.02",
#       "t12.2022.08.11",
#       "t12.2022.08.13",
#       "t12.2022.08.18",
#       "t12.2022.08.23",
#       "t12.2022.08.25"
#     ],
#     "feature_dim": 128,
#     "feature_policy": "area6v_v1"
#   }
# }
#
# stats_output_path: /content/drive/MyDrive/utah_ssl/data/stats/split_feature_stats/raw/brain2text24/competition_train/tx_only/global_v1.pt

# %%
import json
import os
import shlex
import subprocess
import threading
import time

PACKAGE_ROOT = REPO_DIR

cmd = [
    'python', '-m', 'experiments.archive.timestep_flexible_ssm.train',
    '--cache-root', str(CACHE_ROOT),
    '--output-root', str(OUTPUT_ROOT),
    '--run-name', RUN_NAME,
    '--dataset', DATASET,
    '--feature-mode', FEATURE_MODE,
    '--normalization-mode', NORMALIZATION_MODE,
    '--train-bin-size-ms', str(TRAIN_BIN_SIZE_MS),
    '--eval-bin-sizes-ms', ','.join(str(item) for item in EVAL_BIN_SIZES_MS),
    '--patch-size-ms', str(PATCH_SIZE_MS),
    '--patch-stride-ms', str(PATCH_STRIDE_MS),
    '--max-steps', str(MAX_STEPS),
    '--batch-size', str(BATCH_SIZE),
    '--learning-rate', str(LEARNING_RATE),
    '--min-learning-rate', str(MIN_LEARNING_RATE),
    '--adam-epsilon', str(ADAM_EPSILON),
    '--val-every-steps', '100',
    '--checkpoint-every-steps', '500',
    '--progress-every-steps', '25',
]
if RESUME_LATEST:
    cmd.append('--resume-latest')
if not SESSION_ADAPTER:
    cmd.append('--disable-session-adapter')
full_cmd = ' '.join(shlex.quote(part) for part in cmd)
pythonpath = f"{PACKAGE_ROOT}:{os.environ.get('PYTHONPATH', '')}"
env = dict(os.environ)
env['PYTHONPATH'] = pythonpath
progress_path = RUN_DIR / 'progress.jsonl'

print(full_cmd)

def _tail_progress(stop_event):
    seen_lines = 0
    while not stop_event.is_set():
        if progress_path.exists():
            lines = [line for line in progress_path.read_text().splitlines() if line.strip()]
            new_lines = lines[seen_lines:]
            for line in new_lines:
                try:
                    payload = json.loads(line)
                except json.JSONDecodeError:
                    print(line)
                    continue
                event = payload.get('event', 'progress')
                step = payload.get('step', '?')
                if event == 'timestep_flexible_train_report':
                    print(f"[train] step={step} ctc={payload.get('train_ctc_bpphone'):.4f} lr={payload.get('learning_rate'):.6f} elapsed={payload.get('elapsed_seconds'):.1f}s")
                elif event == 'timestep_flexible_val_report':
                    msg = [f"[val] step={step}"]
                    if 'val_20ms_ctc_bpphone' in payload:
                        msg.append(f"20ms_ctc={payload['val_20ms_ctc_bpphone']:.4f}")
                    if 'val_20ms_phoneme_error_rate' in payload:
                        msg.append(f"20ms_per={payload['val_20ms_phoneme_error_rate']:.4f}")
                    if 'val_40ms_ctc_bpphone' in payload:
                        msg.append(f"40ms_ctc={payload['val_40ms_ctc_bpphone']:.4f}")
                    if 'val_40ms_phoneme_error_rate' in payload:
                        msg.append(f"40ms_per={payload['val_40ms_phoneme_error_rate']:.4f}")
                    print(' '.join(msg))
                else:
                    print(payload)
            seen_lines = len(lines)
        time.sleep(5)

stop_event = threading.Event()
tail_thread = threading.Thread(target=_tail_progress, args=(stop_event,), daemon=True)
tail_thread.start()

process = subprocess.Popen(
    cmd,
    cwd=str(PACKAGE_ROOT),
    env=env,
    text=True,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    bufsize=1,
)
try:
    for line in process.stdout:
        if line.strip():
            print(line.rstrip())
    return_code = process.wait()
finally:
    stop_event.set()
    tail_thread.join(timeout=1)

if progress_path.exists():
    final_lines = [line for line in progress_path.read_text().splitlines() if line.strip()]
    for line in final_lines[-5:]:
        try:
            print(json.loads(line))
        except json.JSONDecodeError:
            print(line)

if return_code != 0:
    raise RuntimeError(f'Training command failed with exit code {return_code}')
# Out:
# python -m experiments.archive.timestep_flexible_ssm.train --cache-root /content/drive/MyDrive/utah_ssl/data/cache_v1 --output-root /content/drive/MyDrive/utah_ssl/outputs/timestep_flexible_ssm --run-name timestep_flexible_s5_tx_only_colab --dataset brain2text24 --feature-mode tx_only --normalization-mode global --train-bin-size-ms 20 --eval-bin-sizes-ms 20,40 --patch-size-ms 280 --patch-stride-ms 80 --max-steps 10000 --batch-size 64 --learning-rate 0.01 --min-learning-rate 0.0001 --adam-epsilon 0.1 --val-every-steps 100 --checkpoint-every-steps 500 --progress-every-steps 25
# [train] step=1 ctc=17.6827 lr=0.000020 elapsed=2.9s
# [train] step=25 ctc=17.6381 lr=0.000260 elapsed=23.7s
# [train] step=50 ctc=10.9691 lr=0.000510 elapsed=43.2s
# [train] step=75 ctc=9.7985 lr=0.000760 elapsed=62.0s
# [train] step=100 ctc=8.4387 lr=0.001010 elapsed=80.7s
# [val] step=100 20ms_ctc=9.9834 20ms_per=0.8694 40ms_ctc=10.0056 40ms_per=0.8654
# [train] step=125 ctc=7.8476 lr=0.001260 elapsed=106.7s
# [train] step=150 ctc=7.9984 lr=0.001510 elapsed=126.6s
# [train] step=175 ctc=7.0528 lr=0.001760 elapsed=145.6s
# [train] step=200 ctc=7.0905 lr=0.002010 elapsed=164.1s
# [val] step=200 20ms_ctc=8.5077 20ms_per=0.8725 40ms_ctc=8.5002 40ms_per=0.8667
# [train] step=225 ctc=6.9472 lr=0.002260 elapsed=191.2s
# [train] step=250 ctc=8.2790 lr=0.002510 elapsed=210.5s
# [train] step=275 ctc=7.6138 lr=0.002760 elapsed=228.4s
# [train] step=300 ctc=7.1451 lr=0.003010 elapsed=247.6s
# [val] step=300 20ms_ctc=7.8545 20ms_per=0.8521 40ms_ctc=7.8533 40ms_per=0.8456
# [train] step=325 ctc=9.1443 lr=0.003260 elapsed=272.8s
# [train] step=350 ctc=6.2146 lr=0.003510 elapsed=292.3s
# [train] step=375 ctc=6.7045 lr=0.003760 elapsed=313.2s
# [train] step=400 ctc=9.3805 lr=0.004010 elapsed=332.0s
# [val] step=400 20ms_ctc=9.2692 20ms_per=0.8437 40ms_ctc=9.2814 40ms_per=0.8421
# [train] step=425 ctc=5.9274 lr=0.004260 elapsed=360.0s
# [train] step=450 ctc=8.3955 lr=0.004510 elapsed=378.3s
# [train] step=475 ctc=7.7395 lr=0.004760 elapsed=395.9s
# [train] step=500 ctc=10.3204 lr=0.005010 elapsed=414.1s
# [val] step=500 20ms_ctc=8.9509 20ms_per=0.8186 40ms_ctc=8.9346 40ms_per=0.8156
# [train] step=525 ctc=7.3246 lr=0.005260 elapsed=441.3s
# [train] step=550 ctc=6.8104 lr=0.005510 elapsed=461.8s
# [train] step=575 ctc=6.3327 lr=0.005760 elapsed=483.7s
# [train] step=600 ctc=10.9972 lr=0.006010 elapsed=501.3s
# [val] step=600 20ms_ctc=9.6261 20ms_per=0.8347 40ms_ctc=9.6193 40ms_per=0.8339
# [train] step=625 ctc=7.0726 lr=0.006260 elapsed=528.6s
# [train] step=650 ctc=6.9851 lr=0.006510 elapsed=548.8s
# [train] step=675 ctc=7.5743 lr=0.006760 elapsed=568.6s
# [train] step=700 ctc=8.3990 lr=0.007010 elapsed=587.5s
# [val] step=700 20ms_ctc=10.2046 20ms_per=0.8434 40ms_ctc=10.2035 40ms_per=0.8413
# [train] step=725 ctc=6.7970 lr=0.007260 elapsed=614.8s
# [train] step=750 ctc=6.9273 lr=0.007510 elapsed=632.6s
# [train] step=775 ctc=8.2987 lr=0.007760 elapsed=652.3s
# [train] step=800 ctc=6.7347 lr=0.008010 elapsed=670.4s
# [val] step=800 20ms_ctc=8.5424 20ms_per=0.8257 40ms_ctc=8.5367 40ms_per=0.8230
# [train] step=825 ctc=7.4655 lr=0.008260 elapsed=697.2s
# [train] step=850 ctc=6.9233 lr=0.008510 elapsed=715.6s
# [train] step=875 ctc=7.5290 lr=0.008760 elapsed=735.8s
# [train] step=900 ctc=6.6023 lr=0.009010 elapsed=755.2s
# [val] step=900 20ms_ctc=11.4531 20ms_per=0.8432 40ms_ctc=11.4287 40ms_per=0.8416
# [train] step=925 ctc=6.7815 lr=0.009260 elapsed=779.8s
# [train] step=950 ctc=6.6714 lr=0.009510 elapsed=797.4s
# [train] step=975 ctc=8.9102 lr=0.009760 elapsed=816.3s
# [train] step=1000 ctc=6.8126 lr=0.010000 elapsed=834.8s
# [val] step=1000 20ms_ctc=7.5719 20ms_per=0.8163 40ms_ctc=7.5847 40ms_per=0.8144
# [train] step=1025 ctc=6.5374 lr=0.010000 elapsed=862.6s
# [train] step=1050 ctc=7.1600 lr=0.009999 elapsed=884.0s
# [train] step=1075 ctc=9.5427 lr=0.009999 elapsed=902.1s
# [train] step=1100 ctc=6.8222 lr=0.009998 elapsed=921.3s
# [val] step=1100 20ms_ctc=7.2154 20ms_per=0.8129 40ms_ctc=7.2270 40ms_per=0.8132
# [train] step=1125 ctc=8.3225 lr=0.009997 elapsed=947.6s
# [train] step=1150 ctc=6.0645 lr=0.009995 elapsed=966.9s
# [train] step=1175 ctc=5.6773 lr=0.009994 elapsed=986.8s
# [train] step=1200 ctc=6.1678 lr=0.009992 elapsed=1006.2s
# [val] step=1200 20ms_ctc=6.4619 20ms_per=0.8213 40ms_ctc=6.4653 40ms_per=0.8203
# [train] step=1225 ctc=7.4564 lr=0.009990 elapsed=1031.9s
# [train] step=1250 ctc=6.5525 lr=0.009987 elapsed=1050.2s
# [train] step=1275 ctc=6.4867 lr=0.009985 elapsed=1068.6s
# [train] step=1300 ctc=6.6059 lr=0.009982 elapsed=1087.0s
# [val] step=1300 20ms_ctc=5.9154 20ms_per=0.7996 40ms_ctc=5.9173 40ms_per=0.7985
# [train] step=1325 ctc=5.5692 lr=0.009979 elapsed=1114.3s
# [train] step=1350 ctc=6.5747 lr=0.009975 elapsed=1134.9s
# [train] step=1375 ctc=5.4322 lr=0.009972 elapsed=1153.5s
# [train] step=1400 ctc=5.6977 lr=0.009968 elapsed=1173.4s
# [val] step=1400 20ms_ctc=6.3088 20ms_per=0.8137 40ms_ctc=6.2911 40ms_per=0.8129
# [train] step=1425 ctc=6.9529 lr=0.009964 elapsed=1199.5s
# [train] step=1450 ctc=8.3997 lr=0.009959 elapsed=1218.0s
# [train] step=1475 ctc=6.1100 lr=0.009955 elapsed=1236.3s
# [train] step=1500 ctc=5.5969 lr=0.009950 elapsed=1255.9s
# [val] step=1500 20ms_ctc=6.0441 20ms_per=0.7750 40ms_ctc=6.0200 40ms_per=0.7729
# [train] step=1525 ctc=5.6719 lr=0.009944 elapsed=1283.9s
# [train] step=1550 ctc=5.9110 lr=0.009939 elapsed=1302.1s
# [train] step=1575 ctc=6.5549 lr=0.009933 elapsed=1320.5s
# [train] step=1600 ctc=5.5091 lr=0.009928 elapsed=1339.1s
# [val] step=1600 20ms_ctc=6.0590 20ms_per=0.7948 40ms_ctc=6.0436 40ms_per=0.7956
# [train] step=1625 ctc=7.0548 lr=0.009921 elapsed=1366.1s
# [train] step=1650 ctc=5.3889 lr=0.009915 elapsed=1386.7s
# [train] step=1675 ctc=5.6760 lr=0.009908 elapsed=1406.8s
# [train] step=1700 ctc=5.6683 lr=0.009901 elapsed=1427.4s
# [val] step=1700 20ms_ctc=5.4512 20ms_per=0.8080 40ms_ctc=5.4336 40ms_per=0.8059
# [train] step=1725 ctc=5.4275 lr=0.009894 elapsed=1453.2s
# [train] step=1750 ctc=5.9792 lr=0.009887 elapsed=1472.5s
# [train] step=1775 ctc=5.6145 lr=0.009879 elapsed=1491.6s
# [train] step=1800 ctc=5.4369 lr=0.009871 elapsed=1513.1s
# [val] step=1800 20ms_ctc=6.0316 20ms_per=0.8315 40ms_ctc=6.0389 40ms_per=0.8313
# [train] step=1825 ctc=5.1955 lr=0.009863 elapsed=1539.4s
# [train] step=1850 ctc=5.3366 lr=0.009855 elapsed=1557.8s
# [train] step=1875 ctc=4.9798 lr=0.009846 elapsed=1577.7s
# [train] step=1900 ctc=5.3192 lr=0.009837 elapsed=1597.6s
# [val] step=1900 20ms_ctc=5.4485 20ms_per=0.7905 40ms_ctc=5.4368 40ms_per=0.7898
# [train] step=1925 ctc=5.0556 lr=0.009828 elapsed=1622.9s
# [train] step=1950 ctc=6.1591 lr=0.009819 elapsed=1641.2s
# [train] step=1975 ctc=4.8785 lr=0.009809 elapsed=1657.8s
# [train] step=2000 ctc=5.8656 lr=0.009799 elapsed=1676.1s
# [val] step=2000 20ms_ctc=6.5084 20ms_per=0.8201 40ms_ctc=6.5013 40ms_per=0.8198
# [train] step=2025 ctc=6.5266 lr=0.009789 elapsed=1702.0s
# [train] step=2050 ctc=5.2331 lr=0.009779 elapsed=1719.5s
# [train] step=2075 ctc=8.8027 lr=0.009769 elapsed=1737.9s
# [train] step=2100 ctc=8.2732 lr=0.009758 elapsed=1757.1s
# [val] step=2100 20ms_ctc=5.9635 20ms_per=0.8388 40ms_ctc=5.9509 40ms_per=0.8367
# [train] step=2125 ctc=4.8835 lr=0.009747 elapsed=1783.1s
# [train] step=2150 ctc=6.0522 lr=0.009735 elapsed=1801.2s
# [train] step=2175 ctc=5.5748 lr=0.009724 elapsed=1819.2s
# [train] step=2200 ctc=4.8881 lr=0.009712 elapsed=1839.2s
# [val] step=2200 20ms_ctc=5.0833 20ms_per=0.7728 40ms_ctc=5.0817 40ms_per=0.7729
# [train] step=2225 ctc=4.9646 lr=0.009700 elapsed=1864.2s
# [train] step=2250 ctc=5.1332 lr=0.009688 elapsed=1884.4s
# [train] step=2275 ctc=5.1105 lr=0.009675 elapsed=1904.1s
# [train] step=2300 ctc=5.2044 lr=0.009663 elapsed=1921.9s
# [val] step=2300 20ms_ctc=5.6247 20ms_per=0.7596 40ms_ctc=5.6139 40ms_per=0.7596
# [train] step=2325 ctc=4.8433 lr=0.009650 elapsed=1947.8s
# [train] step=2350 ctc=5.3428 lr=0.009637 elapsed=1968.7s
# [train] step=2375 ctc=4.7039 lr=0.009623 elapsed=1987.7s
# [train] step=2400 ctc=5.0170 lr=0.009610 elapsed=2008.3s
# [val] step=2400 20ms_ctc=5.0743 20ms_per=0.7992 40ms_ctc=5.0571 40ms_per=0.7980
# [train] step=2425 ctc=5.4057 lr=0.009596 elapsed=2035.7s
# [train] step=2450 ctc=5.4314 lr=0.009582 elapsed=2053.7s
# [train] step=2475 ctc=4.7372 lr=0.009567 elapsed=2075.4s
# [train] step=2500 ctc=4.7794 lr=0.009553 elapsed=2093.9s
# [val] step=2500 20ms_ctc=5.4079 20ms_per=0.8110 40ms_ctc=5.4138 40ms_per=0.8100
# [train] step=2525 ctc=5.5522 lr=0.009538 elapsed=2119.8s
# [train] step=2550 ctc=4.7445 lr=0.009523 elapsed=2139.1s
# [train] step=2575 ctc=4.5734 lr=0.009508 elapsed=2157.6s
# [train] step=2600 ctc=4.5894 lr=0.009492 elapsed=2176.2s
# [val] step=2600 20ms_ctc=5.1259 20ms_per=0.7585 40ms_ctc=5.1190 40ms_per=0.7566
# [train] step=2625 ctc=4.7992 lr=0.009476 elapsed=2204.4s
# [train] step=2650 ctc=4.5019 lr=0.009460 elapsed=2223.5s
# [train] step=2675 ctc=4.6246 lr=0.009444 elapsed=2243.7s
# [train] step=2700 ctc=4.9351 lr=0.009428 elapsed=2264.0s
# [val] step=2700 20ms_ctc=4.6938 20ms_per=0.7997 40ms_ctc=4.6929 40ms_per=0.7974
# [train] step=2725 ctc=4.6013 lr=0.009411 elapsed=2290.2s
# [train] step=2750 ctc=4.7172 lr=0.009395 elapsed=2308.9s
# [train] step=2775 ctc=4.5389 lr=0.009377 elapsed=2328.2s
# [train] step=2800 ctc=5.0639 lr=0.009360 elapsed=2349.0s
# [val] step=2800 20ms_ctc=4.9456 20ms_per=0.7345 40ms_ctc=4.9408 40ms_per=0.7322
# [train] step=2825 ctc=4.6224 lr=0.009343 elapsed=2374.2s
# [train] step=2850 ctc=5.0730 lr=0.009325 elapsed=2394.7s
# [train] step=2875 ctc=4.5070 lr=0.009307 elapsed=2413.0s
# [train] step=2900 ctc=4.5521 lr=0.009289 elapsed=2434.4s
# [val] step=2900 20ms_ctc=4.6056 20ms_per=0.7516 40ms_ctc=4.6036 40ms_per=0.7511
# [train] step=2925 ctc=4.5871 lr=0.009271 elapsed=2460.6s
# [train] step=2950 ctc=4.4711 lr=0.009252 elapsed=2479.9s
# [train] step=2975 ctc=5.0220 lr=0.009233 elapsed=2499.7s
# [train] step=3000 ctc=4.4293 lr=0.009214 elapsed=2520.5s
# [val] step=3000 20ms_ctc=4.8202 20ms_per=0.7190 40ms_ctc=4.8081 40ms_per=0.7206
# [train] step=3025 ctc=5.2753 lr=0.009195 elapsed=2548.8s
# [train] step=3050 ctc=4.1844 lr=0.009176 elapsed=2566.3s
# [train] step=3075 ctc=5.1235 lr=0.009156 elapsed=2584.8s
# [train] step=3100 ctc=4.8031 lr=0.009136 elapsed=2604.5s
# [val] step=3100 20ms_ctc=4.4472 20ms_per=0.7370 40ms_ctc=4.4461 40ms_per=0.7375
# [train] step=3125 ctc=4.6865 lr=0.009116 elapsed=2629.2s
# [train] step=3150 ctc=4.4093 lr=0.009096 elapsed=2647.2s
# [train] step=3175 ctc=4.1312 lr=0.009075 elapsed=2665.3s
# [train] step=3200 ctc=4.4443 lr=0.009055 elapsed=2684.1s
# [val] step=3200 20ms_ctc=4.4887 20ms_per=0.7376 40ms_ctc=4.4872 40ms_per=0.7373
# [train] step=3225 ctc=4.5494 lr=0.009034 elapsed=2709.8s
# [train] step=3250 ctc=4.4806 lr=0.009013 elapsed=2727.3s
# [train] step=3275 ctc=4.4760 lr=0.008991 elapsed=2746.6s
# [train] step=3300 ctc=4.3474 lr=0.008970 elapsed=2767.8s
# [val] step=3300 20ms_ctc=4.5397 20ms_per=0.7593 40ms_ctc=4.5401 40ms_per=0.7587
# [train] step=3325 ctc=4.3322 lr=0.008948 elapsed=2794.8s
# [train] step=3350 ctc=4.2848 lr=0.008926 elapsed=2815.4s
# [train] step=3375 ctc=4.3019 lr=0.008904 elapsed=2834.1s
# [train] step=3400 ctc=4.2800 lr=0.008882 elapsed=2851.9s
# [val] step=3400 20ms_ctc=4.5097 20ms_per=0.7093 40ms_ctc=4.5042 40ms_per=0.7092
# [train] step=3425 ctc=4.2439 lr=0.008860 elapsed=2878.7s
# [train] step=3450 ctc=4.2117 lr=0.008837 elapsed=2897.2s
# [train] step=3475 ctc=4.2101 lr=0.008814 elapsed=2916.1s
# [train] step=3500 ctc=4.0314 lr=0.008791 elapsed=2933.0s
# [val] step=3500 20ms_ctc=4.4077 20ms_per=0.7064 40ms_ctc=4.4019 40ms_per=0.7056
# [train] step=3525 ctc=4.0422 lr=0.008768 elapsed=2960.1s
# [train] step=3550 ctc=4.2018 lr=0.008744 elapsed=2977.7s
# [train] step=3575 ctc=3.9508 lr=0.008721 elapsed=2998.7s
# [train] step=3600 ctc=4.4350 lr=0.008697 elapsed=3016.0s
# [val] step=3600 20ms_ctc=4.2765 20ms_per=0.7403 40ms_ctc=4.2756 40ms_per=0.7400
# [train] step=3625 ctc=3.9263 lr=0.008673 elapsed=3041.6s
# [train] step=3650 ctc=4.1234 lr=0.008649 elapsed=3059.7s
# [train] step=3675 ctc=4.2127 lr=0.008624 elapsed=3078.4s
# [train] step=3700 ctc=4.4827 lr=0.008600 elapsed=3098.3s
# [val] step=3700 20ms_ctc=4.2355 20ms_per=0.7570 40ms_ctc=4.2369 40ms_per=0.7561
# [train] step=3725 ctc=4.1447 lr=0.008575 elapsed=3122.6s
# [train] step=3750 ctc=3.7211 lr=0.008550 elapsed=3142.6s
# [train] step=3775 ctc=4.1629 lr=0.008525 elapsed=3162.2s
# [train] step=3800 ctc=4.0408 lr=0.008500 elapsed=3182.3s
# [val] step=3800 20ms_ctc=4.2916 20ms_per=0.7024 40ms_ctc=4.2909 40ms_per=0.7016
# [train] step=3825 ctc=4.1520 lr=0.008474 elapsed=3209.5s
# [train] step=3850 ctc=4.2235 lr=0.008449 elapsed=3227.3s
# [train] step=3875 ctc=4.2282 lr=0.008423 elapsed=3246.1s
# [train] step=3900 ctc=3.9886 lr=0.008397 elapsed=3263.1s
# [val] step=3900 20ms_ctc=4.3647 20ms_per=0.6812 40ms_ctc=4.3593 40ms_per=0.6810
# [train] step=3925 ctc=4.1156 lr=0.008371 elapsed=3289.3s
# [train] step=3950 ctc=4.0174 lr=0.008345 elapsed=3307.8s
# [train] step=3975 ctc=4.2420 lr=0.008318 elapsed=3327.0s
# [train] step=4000 ctc=4.3407 lr=0.008292 elapsed=3348.1s
# [val] step=4000 20ms_ctc=4.1513 20ms_per=0.6909 40ms_ctc=4.1497 40ms_per=0.6896
# [train] step=4025 ctc=4.3084 lr=0.008265 elapsed=3375.9s
# [train] step=4050 ctc=3.8287 lr=0.008238 elapsed=3395.1s
# [train] step=4075 ctc=4.0991 lr=0.008211 elapsed=3415.5s
# [train] step=4100 ctc=4.0201 lr=0.008183 elapsed=3434.4s
# [val] step=4100 20ms_ctc=4.2266 20ms_per=0.6808 40ms_ctc=4.2247 40ms_per=0.6787
# [train] step=4125 ctc=3.9751 lr=0.008156 elapsed=3459.3s
# [train] step=4150 ctc=3.9446 lr=0.008128 elapsed=3478.1s
# [train] step=4175 ctc=3.6940 lr=0.008101 elapsed=3496.6s
# [train] step=4200 ctc=3.6340 lr=0.008073 elapsed=3516.6s
# [val] step=4200 20ms_ctc=4.1763 20ms_per=0.6913 40ms_ctc=4.1688 40ms_per=0.6904
# [train] step=4225 ctc=4.0811 lr=0.008045 elapsed=3543.1s
# [train] step=4250 ctc=4.1435 lr=0.008016 elapsed=3564.4s
# [train] step=4275 ctc=4.1584 lr=0.007988 elapsed=3581.9s
# [train] step=4300 ctc=4.1721 lr=0.007960 elapsed=3599.7s
# [val] step=4300 20ms_ctc=4.1489 20ms_per=0.6767 40ms_ctc=4.1436 40ms_per=0.6780
# [train] step=4325 ctc=4.0243 lr=0.007931 elapsed=3626.8s
# [train] step=4350 ctc=3.5713 lr=0.007902 elapsed=3646.1s
# [train] step=4375 ctc=3.9013 lr=0.007873 elapsed=3666.0s
# [train] step=4400 ctc=4.1896 lr=0.007844 elapsed=3685.7s
# [val] step=4400 20ms_ctc=3.9846 20ms_per=0.6827 40ms_ctc=3.9811 40ms_per=0.6838
# [train] step=4425 ctc=3.9076 lr=0.007815 elapsed=3712.3s
# [train] step=4450 ctc=4.1088 lr=0.007785 elapsed=3733.0s
# [train] step=4475 ctc=3.7420 lr=0.007756 elapsed=3750.7s
# [train] step=4500 ctc=3.8095 lr=0.007726 elapsed=3770.6s
# [val] step=4500 20ms_ctc=3.9400 20ms_per=0.6807 40ms_ctc=3.9374 40ms_per=0.6811
# [train] step=4525 ctc=4.2073 lr=0.007696 elapsed=3795.7s
# [train] step=4550 ctc=3.8589 lr=0.007666 elapsed=3815.1s
# [train] step=4575 ctc=3.9336 lr=0.007636 elapsed=3832.6s
# [train] step=4600 ctc=4.0245 lr=0.007606 elapsed=3851.7s
# [val] step=4600 20ms_ctc=3.9980 20ms_per=0.6578 40ms_ctc=3.9910 40ms_per=0.6578
# [train] step=4625 ctc=4.0557 lr=0.007576 elapsed=3876.4s
# [train] step=4650 ctc=3.6127 lr=0.007545 elapsed=3895.3s
# [train] step=4675 ctc=3.7570 lr=0.007515 elapsed=3914.3s
# [train] step=4700 ctc=4.1332 lr=0.007484 elapsed=3932.6s
# [val] step=4700 20ms_ctc=3.8006 20ms_per=0.6855 40ms_ctc=3.7978 40ms_per=0.6844
# [train] step=4725 ctc=3.7081 lr=0.007453 elapsed=3958.2s
# [train] step=4750 ctc=3.9175 lr=0.007422 elapsed=3977.9s
# [train] step=4775 ctc=3.5363 lr=0.007391 elapsed=3996.7s
# [train] step=4800 ctc=3.7526 lr=0.007360 elapsed=4015.7s
# [val] step=4800 20ms_ctc=3.8408 20ms_per=0.6603 40ms_ctc=3.8376 40ms_per=0.6601
# [train] step=4825 ctc=3.3411 lr=0.007329 elapsed=4040.1s
# [train] step=4850 ctc=3.8126 lr=0.007297 elapsed=4059.5s
# [train] step=4875 ctc=3.8954 lr=0.007266 elapsed=4078.7s
# [train] step=4900 ctc=3.7213 lr=0.007234 elapsed=4099.3s
# [val] step=4900 20ms_ctc=3.8060 20ms_per=0.6583 40ms_ctc=3.8030 40ms_per=0.6590
# [train] step=4925 ctc=3.8472 lr=0.007202 elapsed=4123.6s
# [train] step=4950 ctc=3.8237 lr=0.007170 elapsed=4143.2s
# [train] step=4975 ctc=3.7144 lr=0.007138 elapsed=4161.8s
# [train] step=5000 ctc=3.5939 lr=0.007106 elapsed=4179.8s
# [val] step=5000 20ms_ctc=3.8589 20ms_per=0.6403 40ms_ctc=3.8549 40ms_per=0.6420
# [train] step=5025 ctc=3.3391 lr=0.007074 elapsed=4208.0s
# [train] step=5050 ctc=3.5337 lr=0.007042 elapsed=4227.6s
# [train] step=5075 ctc=3.5298 lr=0.007009 elapsed=4246.4s
# [train] step=5100 ctc=3.3690 lr=0.006977 elapsed=4266.2s
# [val] step=5100 20ms_ctc=3.7764 20ms_per=0.6438 40ms_ctc=3.7721 40ms_per=0.6434
# [train] step=5125 ctc=3.5294 lr=0.006944 elapsed=4292.4s
# [train] step=5150 ctc=3.7932 lr=0.006912 elapsed=4312.0s
# [train] step=5175 ctc=3.8326 lr=0.006879 elapsed=4330.2s
# [train] step=5200 ctc=3.3576 lr=0.006846 elapsed=4348.3s
# [val] step=5200 20ms_ctc=3.6735 20ms_per=0.6384 40ms_ctc=3.6723 40ms_per=0.6394
# [train] step=5225 ctc=3.3419 lr=0.006813 elapsed=4374.3s
# [train] step=5250 ctc=3.5702 lr=0.006780 elapsed=4393.0s
# [train] step=5275 ctc=3.4897 lr=0.006747 elapsed=4411.9s
# [train] step=5300 ctc=3.4828 lr=0.006713 elapsed=4429.6s
# [val] step=5300 20ms_ctc=3.6398 20ms_per=0.6409 40ms_ctc=3.6416 40ms_per=0.6414
# [train] step=5325 ctc=3.7801 lr=0.006680 elapsed=4455.1s
# [train] step=5350 ctc=3.6000 lr=0.006647 elapsed=4474.2s
# [train] step=5375 ctc=3.8549 lr=0.006613 elapsed=4493.9s
# [train] step=5400 ctc=3.3681 lr=0.006580 elapsed=4512.4s
# [val] step=5400 20ms_ctc=3.5880 20ms_per=0.6353 40ms_ctc=3.5901 40ms_per=0.6365
# [train] step=5425 ctc=3.8261 lr=0.006546 elapsed=4538.3s
# [train] step=5450 ctc=3.6393 lr=0.006512 elapsed=4557.5s
# [train] step=5475 ctc=3.8248 lr=0.006478 elapsed=4574.0s
# [train] step=5500 ctc=3.7801 lr=0.006445 elapsed=4592.7s
# [val] step=5500 20ms_ctc=3.5488 20ms_per=0.6399 40ms_ctc=3.5519 40ms_per=0.6405
# [train] step=5525 ctc=3.5531 lr=0.006411 elapsed=4618.9s
# [train] step=5550 ctc=3.5250 lr=0.006377 elapsed=4638.1s
# [train] step=5575 ctc=3.4977 lr=0.006343 elapsed=4656.9s
# [train] step=5600 ctc=3.5062 lr=0.006308 elapsed=4677.2s
# [val] step=5600 20ms_ctc=3.4887 20ms_per=0.6402 40ms_ctc=3.4896 40ms_per=0.6404
# [train] step=5625 ctc=3.5269 lr=0.006274 elapsed=4702.1s
# [train] step=5650 ctc=3.1467 lr=0.006240 elapsed=4722.4s
# [train] step=5675 ctc=3.8475 lr=0.006206 elapsed=4741.0s
# [train] step=5700 ctc=3.7661 lr=0.006171 elapsed=4759.6s
# [val] step=5700 20ms_ctc=3.4709 20ms_per=0.6418 40ms_ctc=3.4700 40ms_per=0.6410
# [train] step=5725 ctc=3.2246 lr=0.006137 elapsed=4787.4s
# [train] step=5750 ctc=3.6356 lr=0.006102 elapsed=4806.2s
# [train] step=5775 ctc=3.5343 lr=0.006068 elapsed=4824.9s
# [train] step=5800 ctc=3.4462 lr=0.006033 elapsed=4844.2s
# [val] step=5800 20ms_ctc=3.4458 20ms_per=0.6315 40ms_ctc=3.4483 40ms_per=0.6321
# [train] step=5825 ctc=3.5263 lr=0.005998 elapsed=4871.0s
# [train] step=5850 ctc=3.3646 lr=0.005964 elapsed=4891.6s
# [train] step=5875 ctc=3.4392 lr=0.005929 elapsed=4911.0s
# [train] step=5900 ctc=3.3649 lr=0.005894 elapsed=4929.9s
# [val] step=5900 20ms_ctc=3.4328 20ms_per=0.6222 40ms_ctc=3.4350 40ms_per=0.6232
# [train] step=5925 ctc=3.3533 lr=0.005859 elapsed=4957.0s
# [train] step=5950 ctc=3.1781 lr=0.005824 elapsed=4975.6s
# [train] step=5975 ctc=3.3840 lr=0.005789 elapsed=4995.5s
# [train] step=6000 ctc=3.4871 lr=0.005754 elapsed=5013.9s
# [val] step=6000 20ms_ctc=3.3948 20ms_per=0.6280 40ms_ctc=3.3997 40ms_per=0.6277
# [train] step=6025 ctc=3.6065 lr=0.005719 elapsed=5039.8s
# [train] step=6050 ctc=3.2901 lr=0.005684 elapsed=5058.4s
# [train] step=6075 ctc=3.5058 lr=0.005649 elapsed=5078.3s
# [train] step=6100 ctc=3.3245 lr=0.005614 elapsed=5098.8s
# [val] step=6100 20ms_ctc=3.3698 20ms_per=0.6280 40ms_ctc=3.3706 40ms_per=0.6285
# [train] step=6125 ctc=3.1578 lr=0.005579 elapsed=5124.2s
# [train] step=6150 ctc=3.5049 lr=0.005544 elapsed=5144.3s
# [train] step=6175 ctc=3.3180 lr=0.005509 elapsed=5162.7s
# [train] step=6200 ctc=3.1504 lr=0.005474 elapsed=5182.8s
# [val] step=6200 20ms_ctc=3.3313 20ms_per=0.6314 40ms_ctc=3.3335 40ms_per=0.6320
# [train] step=6225 ctc=3.4452 lr=0.005438 elapsed=5209.3s
# [train] step=6250 ctc=3.4219 lr=0.005403 elapsed=5229.4s
# [train] step=6275 ctc=3.0057 lr=0.005368 elapsed=5249.0s
# [train] step=6300 ctc=3.3733 lr=0.005333 elapsed=5269.7s
# [val] step=6300 20ms_ctc=3.3220 20ms_per=0.6197 40ms_ctc=3.3260 40ms_per=0.6205
# [train] step=6325 ctc=3.6235 lr=0.005297 elapsed=5295.4s
# [train] step=6350 ctc=3.4439 lr=0.005262 elapsed=5314.6s
# [train] step=6375 ctc=3.1821 lr=0.005227 elapsed=5332.1s
# [train] step=6400 ctc=3.4519 lr=0.005191 elapsed=5351.2s
# [val] step=6400 20ms_ctc=3.2716 20ms_per=0.6189 40ms_ctc=3.2743 40ms_per=0.6185
# [train] step=6425 ctc=3.3087 lr=0.005156 elapsed=5375.7s
# [train] step=6450 ctc=3.0912 lr=0.005121 elapsed=5393.6s
# [train] step=6475 ctc=3.1233 lr=0.005085 elapsed=5412.5s
# [train] step=6500 ctc=3.0403 lr=0.005050 elapsed=5433.6s
# [val] step=6500 20ms_ctc=3.2818 20ms_per=0.6111 40ms_ctc=3.2859 40ms_per=0.6123
# [train] step=6525 ctc=3.2019 lr=0.005015 elapsed=5462.3s
# [train] step=6550 ctc=3.5512 lr=0.004979 elapsed=5480.7s
# [train] step=6575 ctc=2.9886 lr=0.004944 elapsed=5500.0s
# [train] step=6600 ctc=3.3470 lr=0.004909 elapsed=5519.8s
# [val] step=6600 20ms_ctc=3.2676 20ms_per=0.5965 40ms_ctc=3.2715 40ms_per=0.5986
# [train] step=6625 ctc=3.0176 lr=0.004873 elapsed=5545.3s
# [train] step=6650 ctc=3.4781 lr=0.004838 elapsed=5565.0s
# [train] step=6675 ctc=3.6390 lr=0.004803 elapsed=5582.5s
# [train] step=6700 ctc=3.5011 lr=0.004767 elapsed=5601.5s
# [val] step=6700 20ms_ctc=3.2139 20ms_per=0.6140 40ms_ctc=3.2171 40ms_per=0.6140
# [train] step=6725 ctc=3.2908 lr=0.004732 elapsed=5627.4s
# [train] step=6750 ctc=3.2783 lr=0.004697 elapsed=5645.2s
# [train] step=6775 ctc=3.2612 lr=0.004662 elapsed=5664.2s
# [train] step=6800 ctc=3.1824 lr=0.004626 elapsed=5683.3s
# [val] step=6800 20ms_ctc=3.2119 20ms_per=0.6081 40ms_ctc=3.2147 40ms_per=0.6082
# [train] step=6825 ctc=3.5307 lr=0.004591 elapsed=5709.2s
# [train] step=6850 ctc=3.3642 lr=0.004556 elapsed=5729.5s
# [train] step=6875 ctc=3.3207 lr=0.004521 elapsed=5746.8s
# [train] step=6900 ctc=3.6335 lr=0.004486 elapsed=5766.6s
# [val] step=6900 20ms_ctc=3.1928 20ms_per=0.6093 40ms_ctc=3.1960 40ms_per=0.6097
# [train] step=6925 ctc=3.4981 lr=0.004451 elapsed=5790.7s
# [train] step=6950 ctc=3.5436 lr=0.004416 elapsed=5810.6s
# [train] step=6975 ctc=3.1069 lr=0.004381 elapsed=5830.8s
# [train] step=7000 ctc=3.4002 lr=0.004346 elapsed=5850.4s
# [val] step=7000 20ms_ctc=3.1890 20ms_per=0.5916 40ms_ctc=3.1926 40ms_per=0.5931
# [train] step=7025 ctc=2.9854 lr=0.004311 elapsed=5877.5s
# [train] step=7050 ctc=3.2295 lr=0.004276 elapsed=5895.8s
# [train] step=7075 ctc=3.5037 lr=0.004241 elapsed=5913.3s
# [train] step=7100 ctc=3.3436 lr=0.004206 elapsed=5930.2s
# [val] step=7100 20ms_ctc=3.1512 20ms_per=0.6094 40ms_ctc=3.1541 40ms_per=0.6121
# [train] step=7125 ctc=3.2051 lr=0.004171 elapsed=5955.2s
# [train] step=7150 ctc=3.2224 lr=0.004136 elapsed=5974.4s
# [train] step=7175 ctc=3.6017 lr=0.004102 elapsed=5995.3s
# [train] step=7200 ctc=3.2477 lr=0.004067 elapsed=6013.8s
# [val] step=7200 20ms_ctc=3.1640 20ms_per=0.5979 40ms_ctc=3.1670 40ms_per=0.5960
# [train] step=7225 ctc=2.9342 lr=0.004032 elapsed=6041.8s
# [train] step=7250 ctc=3.4083 lr=0.003998 elapsed=6060.7s
# [train] step=7275 ctc=3.0821 lr=0.003963 elapsed=6081.4s
# [train] step=7300 ctc=3.4197 lr=0.003929 elapsed=6099.7s
# [val] step=7300 20ms_ctc=3.1287 20ms_per=0.5865 40ms_ctc=3.1339 40ms_per=0.5870
# [train] step=7325 ctc=3.4121 lr=0.003894 elapsed=6125.1s
# [train] step=7350 ctc=3.0977 lr=0.003860 elapsed=6145.0s
# [train] step=7375 ctc=3.0864 lr=0.003826 elapsed=6163.1s
# [train] step=7400 ctc=3.2808 lr=0.003792 elapsed=6181.3s
# [val] step=7400 20ms_ctc=3.1305 20ms_per=0.5882 40ms_ctc=3.1365 40ms_per=0.5889
# [train] step=7425 ctc=3.1204 lr=0.003757 elapsed=6209.1s
# [train] step=7450 ctc=3.2248 lr=0.003723 elapsed=6226.5s
# [train] step=7475 ctc=3.2046 lr=0.003689 elapsed=6245.2s
# [train] step=7500 ctc=3.1478 lr=0.003655 elapsed=6264.7s
# [val] step=7500 20ms_ctc=3.1375 20ms_per=0.5776 40ms_ctc=3.1428 40ms_per=0.5774
# [train] step=7525 ctc=3.3287 lr=0.003622 elapsed=6290.1s
# [train] step=7550 ctc=3.0549 lr=0.003588 elapsed=6309.4s
# [train] step=7575 ctc=3.2971 lr=0.003554 elapsed=6329.6s
# [train] step=7600 ctc=3.2047 lr=0.003520 elapsed=6348.5s
# [val] step=7600 20ms_ctc=3.1152 20ms_per=0.5771 40ms_ctc=3.1192 40ms_per=0.5777
# [train] step=7625 ctc=3.2609 lr=0.003487 elapsed=6373.8s
# [train] step=7650 ctc=3.1597 lr=0.003453 elapsed=6393.2s
# [train] step=7675 ctc=3.0649 lr=0.003420 elapsed=6412.5s
# [train] step=7700 ctc=2.8630 lr=0.003387 elapsed=6432.5s
# [val] step=7700 20ms_ctc=3.0692 20ms_per=0.5868 40ms_ctc=3.0731 40ms_per=0.5879
# [train] step=7725 ctc=3.2372 lr=0.003353 elapsed=6457.5s
# [train] step=7750 ctc=3.5447 lr=0.003320 elapsed=6475.9s
# [train] step=7775 ctc=3.2582 lr=0.003287 elapsed=6494.9s
# [train] step=7800 ctc=3.4568 lr=0.003254 elapsed=6514.8s
# [val] step=7800 20ms_ctc=3.0728 20ms_per=0.5842 40ms_ctc=3.0786 40ms_per=0.5847
# [train] step=7825 ctc=3.0346 lr=0.003221 elapsed=6541.6s
# [train] step=7850 ctc=3.1343 lr=0.003188 elapsed=6558.8s
# [train] step=7875 ctc=3.2010 lr=0.003156 elapsed=6578.6s
# [train] step=7900 ctc=3.3634 lr=0.003123 elapsed=6596.3s
# [val] step=7900 20ms_ctc=3.0565 20ms_per=0.5868 40ms_ctc=3.0635 40ms_per=0.5880
# [train] step=7925 ctc=3.1469 lr=0.003091 elapsed=6621.7s
# [train] step=7950 ctc=2.8755 lr=0.003058 elapsed=6640.7s
# [train] step=7975 ctc=3.0776 lr=0.003026 elapsed=6660.7s
# [train] step=8000 ctc=3.1683 lr=0.002994 elapsed=6681.6s
# [val] step=8000 20ms_ctc=3.0649 20ms_per=0.5696 40ms_ctc=3.0702 40ms_per=0.5721
# [train] step=8025 ctc=3.0621 lr=0.002962 elapsed=6707.0s
# [train] step=8050 ctc=3.1716 lr=0.002930 elapsed=6726.4s
# [train] step=8075 ctc=2.8355 lr=0.002898 elapsed=6745.3s
# [train] step=8100 ctc=3.0559 lr=0.002866 elapsed=6763.5s
# [val] step=8100 20ms_ctc=3.0323 20ms_per=0.5773 40ms_ctc=3.0397 40ms_per=0.5777
# [train] step=8125 ctc=2.9241 lr=0.002834 elapsed=6787.4s
# [train] step=8150 ctc=3.0144 lr=0.002803 elapsed=6807.2s
# [train] step=8175 ctc=2.9114 lr=0.002771 elapsed=6825.9s
# [train] step=8200 ctc=3.0779 lr=0.002740 elapsed=6843.9s
# [val] step=8200 20ms_ctc=3.0303 20ms_per=0.5748 40ms_ctc=3.0375 40ms_per=0.5758
# [train] step=8225 ctc=3.3270 lr=0.002709 elapsed=6870.6s
# [train] step=8250 ctc=3.4992 lr=0.002678 elapsed=6890.7s
# [train] step=8275 ctc=3.2155 lr=0.002647 elapsed=6911.3s
# [train] step=8300 ctc=3.1251 lr=0.002616 elapsed=6928.7s
# [val] step=8300 20ms_ctc=3.0228 20ms_per=0.5808 40ms_ctc=3.0305 40ms_per=0.5810
# [train] step=8325 ctc=3.4030 lr=0.002585 elapsed=6954.5s
# [train] step=8350 ctc=3.4944 lr=0.002555 elapsed=6973.6s
# [train] step=8375 ctc=3.2298 lr=0.002524 elapsed=6991.2s
# [train] step=8400 ctc=3.1300 lr=0.002494 elapsed=7009.7s
# [val] step=8400 20ms_ctc=3.0085 20ms_per=0.5758 40ms_ctc=3.0129 40ms_per=0.5764
# [train] step=8425 ctc=2.9392 lr=0.002464 elapsed=7035.2s
# [train] step=8450 ctc=3.0202 lr=0.002434 elapsed=7055.6s
# [train] step=8475 ctc=3.0599 lr=0.002404 elapsed=7073.8s
# [train] step=8500 ctc=3.0367 lr=0.002374 elapsed=7092.1s
# [val] step=8500 20ms_ctc=3.0138 20ms_per=0.5760 40ms_ctc=3.0197 40ms_per=0.5766
# [train] step=8525 ctc=2.8655 lr=0.002344 elapsed=7118.8s
# [train] step=8550 ctc=3.3577 lr=0.002315 elapsed=7138.9s
# [train] step=8575 ctc=3.0449 lr=0.002285 elapsed=7157.2s
# [train] step=8600 ctc=3.1445 lr=0.002256 elapsed=7175.7s
# [val] step=8600 20ms_ctc=2.9941 20ms_per=0.5757 40ms_ctc=3.0011 40ms_per=0.5782
# [train] step=8625 ctc=3.3130 lr=0.002227 elapsed=7202.3s
# [train] step=8650 ctc=3.3080 lr=0.002198 elapsed=7222.6s
# [train] step=8675 ctc=2.7695 lr=0.002169 elapsed=7241.2s
# [train] step=8700 ctc=2.8625 lr=0.002140 elapsed=7260.0s
# [val] step=8700 20ms_ctc=2.9900 20ms_per=0.5719 40ms_ctc=2.9965 40ms_per=0.5715
# [train] step=8725 ctc=2.8330 lr=0.002112 elapsed=7284.4s
# [train] step=8750 ctc=2.8181 lr=0.002084 elapsed=7303.1s
# [train] step=8775 ctc=3.0265 lr=0.002055 elapsed=7321.8s
# [train] step=8800 ctc=3.0708 lr=0.002027 elapsed=7340.2s
# [val] step=8800 20ms_ctc=2.9820 20ms_per=0.5719 40ms_ctc=2.9885 40ms_per=0.5712
# [train] step=8825 ctc=3.2959 lr=0.001999 elapsed=7365.8s
# [train] step=8850 ctc=3.0086 lr=0.001972 elapsed=7386.5s
# [train] step=8875 ctc=2.8118 lr=0.001944 elapsed=7406.2s
# [train] step=8900 ctc=2.9487 lr=0.001917 elapsed=7425.5s
# [val] step=8900 20ms_ctc=2.9763 20ms_per=0.5733 40ms_ctc=2.9845 40ms_per=0.5735
# [train] step=8925 ctc=3.2033 lr=0.001889 elapsed=7450.3s
# [train] step=8950 ctc=3.0955 lr=0.001862 elapsed=7471.7s
# [train] step=8975 ctc=3.0919 lr=0.001835 elapsed=7492.8s
# [train] step=9000 ctc=3.0664 lr=0.001808 elapsed=7512.1s
# [val] step=9000 20ms_ctc=2.9621 20ms_per=0.5711 40ms_ctc=2.9697 40ms_per=0.5727
# [train] step=9025 ctc=3.1509 lr=0.001782 elapsed=7539.2s
# [train] step=9050 ctc=2.9347 lr=0.001755 elapsed=7558.5s
# [train] step=9075 ctc=3.0179 lr=0.001729 elapsed=7578.5s
# [train] step=9100 ctc=3.0580 lr=0.001703 elapsed=7596.4s
# [val] step=9100 20ms_ctc=2.9620 20ms_per=0.5652 40ms_ctc=2.9691 40ms_per=0.5684
# [train] step=9125 ctc=3.1185 lr=0.001677 elapsed=7623.5s
# [train] step=9150 ctc=3.0525 lr=0.001651 elapsed=7643.3s
# [train] step=9175 ctc=2.9751 lr=0.001626 elapsed=7662.1s
# [train] step=9200 ctc=3.0319 lr=0.001600 elapsed=7681.5s
# [val] step=9200 20ms_ctc=2.9568 20ms_per=0.5661 40ms_ctc=2.9636 40ms_per=0.5669
# [train] step=9225 ctc=2.8241 lr=0.001575 elapsed=7705.9s
# [train] step=9250 ctc=2.8802 lr=0.001550 elapsed=7724.0s
# [train] step=9275 ctc=2.9549 lr=0.001525 elapsed=7742.1s
# [train] step=9300 ctc=3.3201 lr=0.001500 elapsed=7762.7s
# [val] step=9300 20ms_ctc=2.9552 20ms_per=0.5608 40ms_ctc=2.9620 40ms_per=0.5633
# [train] step=9325 ctc=3.1226 lr=0.001476 elapsed=7787.8s
# [train] step=9350 ctc=2.9886 lr=0.001451 elapsed=7806.2s
# [train] step=9375 ctc=2.8274 lr=0.001427 elapsed=7826.7s
# [train] step=9400 ctc=3.0375 lr=0.001403 elapsed=7846.0s
# [val] step=9400 20ms_ctc=2.9539 20ms_per=0.5597 40ms_ctc=2.9600 40ms_per=0.5603
# [train] step=9425 ctc=3.0144 lr=0.001379 elapsed=7870.9s
# [train] step=9450 ctc=2.9552 lr=0.001356 elapsed=7889.3s
# [train] step=9475 ctc=3.1516 lr=0.001332 elapsed=7907.9s
# [train] step=9500 ctc=2.8488 lr=0.001309 elapsed=7925.7s
# [val] step=9500 20ms_ctc=2.9434 20ms_per=0.5648 40ms_ctc=2.9504 40ms_per=0.5649
# [train] step=9525 ctc=3.0613 lr=0.001286 elapsed=7950.8s
# [train] step=9550 ctc=2.7910 lr=0.001263 elapsed=7968.7s
# [train] step=9575 ctc=3.1633 lr=0.001240 elapsed=7988.3s
# [train] step=9600 ctc=2.7785 lr=0.001218 elapsed=8006.5s
# [val] step=9600 20ms_ctc=2.9366 20ms_per=0.5617 40ms_ctc=2.9426 40ms_per=0.5638
# [train] step=9625 ctc=3.2563 lr=0.001196 elapsed=8032.3s
# [train] step=9650 ctc=2.7574 lr=0.001174 elapsed=8049.9s
# [train] step=9675 ctc=3.1216 lr=0.001152 elapsed=8068.1s
# [train] step=9700 ctc=2.6963 lr=0.001130 elapsed=8087.6s
# [val] step=9700 20ms_ctc=2.9362 20ms_per=0.5625 40ms_ctc=2.9423 40ms_per=0.5649
# [train] step=9725 ctc=2.9167 lr=0.001109 elapsed=8114.9s
# [train] step=9750 ctc=3.1166 lr=0.001087 elapsed=8134.6s
# [train] step=9775 ctc=2.9861 lr=0.001066 elapsed=8153.1s
# [train] step=9800 ctc=2.7105 lr=0.001045 elapsed=8172.2s
# [val] step=9800 20ms_ctc=2.9337 20ms_per=0.5589 40ms_ctc=2.9409 40ms_per=0.5597
# [train] step=9825 ctc=3.2197 lr=0.001025 elapsed=8199.4s
# [train] step=9850 ctc=3.1649 lr=0.001004 elapsed=8219.2s
# [train] step=9875 ctc=3.0825 lr=0.000984 elapsed=8238.5s
# [train] step=9900 ctc=2.8896 lr=0.000964 elapsed=8258.7s
# [val] step=9900 20ms_ctc=2.9321 20ms_per=0.5596 40ms_ctc=2.9397 40ms_per=0.5604
# [train] step=9925 ctc=3.4330 lr=0.000944 elapsed=8284.4s
# [train] step=9950 ctc=2.7777 lr=0.000924 elapsed=8303.3s
# [train] step=9975 ctc=3.1101 lr=0.000905 elapsed=8322.9s
# [train] step=10000 ctc=3.0759 lr=0.000886 elapsed=8340.9s
# [val] step=10000 20ms_ctc=2.9248 20ms_per=0.5619 40ms_ctc=2.9319 40ms_per=0.5630
# [train] step=10025 ctc=2.8323 lr=0.000867 elapsed=8366.9s
# [train] step=10050 ctc=2.9796 lr=0.000848 elapsed=8385.3s
# [train] step=10075 ctc=2.9256 lr=0.000829 elapsed=8405.8s
# [train] step=10100 ctc=3.3659 lr=0.000811 elapsed=8424.2s
# [val] step=10100 20ms_ctc=2.9156 20ms_per=0.5625 40ms_ctc=2.9224 40ms_per=0.5635
# [train] step=10125 ctc=2.9101 lr=0.000793 elapsed=8449.3s
# [train] step=10150 ctc=3.0968 lr=0.000775 elapsed=8470.0s
# [train] step=10175 ctc=2.8259 lr=0.000757 elapsed=8487.8s
# [train] step=10200 ctc=3.3794 lr=0.000740 elapsed=8506.4s
# [val] step=10200 20ms_ctc=2.9210 20ms_per=0.5587 40ms_ctc=2.9269 40ms_per=0.5595
# [train] step=10225 ctc=3.1383 lr=0.000723 elapsed=8532.5s
# [train] step=10250 ctc=3.2553 lr=0.000705 elapsed=8550.8s
# [train] step=10275 ctc=3.1717 lr=0.000689 elapsed=8568.9s
# [train] step=10300 ctc=3.2561 lr=0.000672 elapsed=8589.2s
# [val] step=10300 20ms_ctc=2.9185 20ms_per=0.5588 40ms_ctc=2.9252 40ms_per=0.5605
# [train] step=10325 ctc=2.7303 lr=0.000656 elapsed=8615.3s
# [train] step=10350 ctc=2.8943 lr=0.000640 elapsed=8634.6s
# [train] step=10375 ctc=3.0289 lr=0.000624 elapsed=8651.9s
# [train] step=10400 ctc=2.9192 lr=0.000608 elapsed=8670.4s
# [val] step=10400 20ms_ctc=2.9119 20ms_per=0.5593 40ms_ctc=2.9194 40ms_per=0.5607
# [train] step=10425 ctc=3.0606 lr=0.000592 elapsed=8696.9s
# [train] step=10450 ctc=2.7682 lr=0.000577 elapsed=8715.8s
# [train] step=10475 ctc=3.3990 lr=0.000562 elapsed=8735.0s
# [train] step=10500 ctc=3.1926 lr=0.000547 elapsed=8754.1s
# [val] step=10500 20ms_ctc=2.9160 20ms_per=0.5574 40ms_ctc=2.9232 40ms_per=0.5599
# [train] step=10525 ctc=2.8393 lr=0.000533 elapsed=8781.4s
# [train] step=10550 ctc=3.4306 lr=0.000518 elapsed=8801.3s
# [train] step=10575 ctc=2.7944 lr=0.000504 elapsed=8821.1s
# [train] step=10600 ctc=3.0208 lr=0.000490 elapsed=8839.1s
# [val] step=10600 20ms_ctc=2.9102 20ms_per=0.5584 40ms_ctc=2.9170 40ms_per=0.5588
# [train] step=10625 ctc=2.9310 lr=0.000477 elapsed=8863.8s
# [train] step=10650 ctc=3.2416 lr=0.000463 elapsed=8881.3s
# [train] step=10675 ctc=2.6727 lr=0.000450 elapsed=8900.9s
# [train] step=10700 ctc=2.8644 lr=0.000437 elapsed=8922.5s
# [val] step=10700 20ms_ctc=2.9119 20ms_per=0.5550 40ms_ctc=2.9189 40ms_per=0.5559
# [train] step=10725 ctc=2.9500 lr=0.000425 elapsed=8949.2s
# [train] step=10750 ctc=3.0719 lr=0.000412 elapsed=8969.2s
# [train] step=10775 ctc=2.6664 lr=0.000400 elapsed=8987.9s
# [train] step=10800 ctc=2.9768 lr=0.000388 elapsed=9007.6s
# [val] step=10800 20ms_ctc=2.9049 20ms_per=0.5580 40ms_ctc=2.9128 40ms_per=0.5600
# [train] step=10825 ctc=2.9726 lr=0.000376 elapsed=9034.1s
# [train] step=10850 ctc=2.9734 lr=0.000365 elapsed=9052.6s
# [train] step=10875 ctc=3.4205 lr=0.000353 elapsed=9072.3s
# [train] step=10900 ctc=3.0384 lr=0.000342 elapsed=9092.0s
# [val] step=10900 20ms_ctc=2.9079 20ms_per=0.5565 40ms_ctc=2.9148 40ms_per=0.5585
# [train] step=10925 ctc=3.0186 lr=0.000331 elapsed=9118.2s
# [train] step=10950 ctc=3.0551 lr=0.000321 elapsed=9136.3s
# [train] step=10975 ctc=2.7100 lr=0.000311 elapsed=9154.5s
# [train] step=11000 ctc=3.0386 lr=0.000301 elapsed=9174.3s
# [val] step=11000 20ms_ctc=2.9061 20ms_per=0.5589 40ms_ctc=2.9126 40ms_per=0.5597
# [train] step=11025 ctc=3.2298 lr=0.000291 elapsed=9198.3s
# [train] step=11050 ctc=3.0989 lr=0.000281 elapsed=9217.2s
# [train] step=11075 ctc=3.0570 lr=0.000272 elapsed=9235.6s
# [train] step=11100 ctc=2.7789 lr=0.000263 elapsed=9254.1s
# [val] step=11100 20ms_ctc=2.9076 20ms_per=0.5545 40ms_ctc=2.9150 40ms_per=0.5565
# [train] step=11125 ctc=3.0130 lr=0.000254 elapsed=9279.0s
# [train] step=11150 ctc=3.2281 lr=0.000245 elapsed=9297.8s
# [train] step=11175 ctc=3.2315 lr=0.000237 elapsed=9317.4s
# [train] step=11200 ctc=2.8659 lr=0.000229 elapsed=9337.1s
# [val] step=11200 20ms_ctc=2.9050 20ms_per=0.5568 40ms_ctc=2.9120 40ms_per=0.5580
# [train] step=11225 ctc=2.6810 lr=0.000221 elapsed=9363.1s
# [train] step=11250 ctc=3.1784 lr=0.000213 elapsed=9382.5s
# [train] step=11275 ctc=2.7153 lr=0.000206 elapsed=9401.4s
# [train] step=11300 ctc=3.2091 lr=0.000199 elapsed=9420.6s
# [val] step=11300 20ms_ctc=2.9045 20ms_per=0.5556 40ms_ctc=2.9118 40ms_per=0.5575
# [train] step=11325 ctc=2.9767 lr=0.000192 elapsed=9448.5s
# [train] step=11350 ctc=3.0241 lr=0.000185 elapsed=9467.5s
# [train] step=11375 ctc=3.2096 lr=0.000179 elapsed=9487.9s
# [train] step=11400 ctc=3.3882 lr=0.000172 elapsed=9507.0s
# [val] step=11400 20ms_ctc=2.8986 20ms_per=0.5586 40ms_ctc=2.9060 40ms_per=0.5604
# [train] step=11425 ctc=2.8429 lr=0.000167 elapsed=9534.0s
# [train] step=11450 ctc=3.0128 lr=0.000161 elapsed=9554.6s
# [train] step=11475 ctc=3.3854 lr=0.000156 elapsed=9575.6s
# [train] step=11500 ctc=3.0215 lr=0.000150 elapsed=9595.2s
# [val] step=11500 20ms_ctc=2.9021 20ms_per=0.5567 40ms_ctc=2.9095 40ms_per=0.5581
# [train] step=11525 ctc=3.1896 lr=0.000145 elapsed=9621.1s
# [train] step=11550 ctc=3.0112 lr=0.000141 elapsed=9639.0s
# [train] step=11575 ctc=2.8828 lr=0.000136 elapsed=9658.4s
# [train] step=11600 ctc=3.1667 lr=0.000132 elapsed=9678.0s
# [val] step=11600 20ms_ctc=2.9008 20ms_per=0.5567 40ms_ctc=2.9082 40ms_per=0.5586
# [train] step=11625 ctc=3.0976 lr=0.000128 elapsed=9703.3s
# [train] step=11650 ctc=3.2394 lr=0.000125 elapsed=9724.4s
# [train] step=11675 ctc=2.8408 lr=0.000121 elapsed=9743.0s
# [train] step=11700 ctc=3.0261 lr=0.000118 elapsed=9762.5s
# [val] step=11700 20ms_ctc=2.8999 20ms_per=0.5559 40ms_ctc=2.9073 40ms_per=0.5577
# [train] step=11725 ctc=2.7016 lr=0.000115 elapsed=9787.5s
# [train] step=11750 ctc=2.9696 lr=0.000113 elapsed=9807.4s
# [train] step=11775 ctc=2.8669 lr=0.000110 elapsed=9826.6s
# [train] step=11800 ctc=3.0233 lr=0.000108 elapsed=9844.7s
# [val] step=11800 20ms_ctc=2.9001 20ms_per=0.5552 40ms_ctc=2.9074 40ms_per=0.5565
# [train] step=11825 ctc=2.6810 lr=0.000106 elapsed=9868.9s
# [train] step=11850 ctc=3.1762 lr=0.000105 elapsed=9887.1s
# [train] step=11875 ctc=3.3663 lr=0.000103 elapsed=9906.5s
# [train] step=11900 ctc=3.0641 lr=0.000102 elapsed=9925.4s
# [val] step=11900 20ms_ctc=2.8996 20ms_per=0.5560 40ms_ctc=2.9071 40ms_per=0.5574
# [train] step=11925 ctc=3.0425 lr=0.000101 elapsed=9951.9s
# [train] step=11950 ctc=3.1435 lr=0.000101 elapsed=9970.8s
# [train] step=11975 ctc=3.2021 lr=0.000100 elapsed=9990.6s
# [train] step=12000 ctc=3.0382 lr=0.000100 elapsed=10011.9s
# [val] step=12000 20ms_ctc=2.8997 20ms_per=0.5561 40ms_ctc=2.9071 40ms_per=0.5569
# <frozen runpy>:128: RuntimeWarning: 'timestep_flexible_ssm.train' found in sys.modules after import of package 'timestep_flexible_ssm', but prior to execution of 'timestep_flexible_ssm.train'; this may result in unpredictable behaviour
# [train] step=1 ctc=17.6827 lr=0.000020 elapsed=2.9s
# [train] step=25 ctc=17.6381 lr=0.000260 elapsed=23.9s
# [train] step=50 ctc=10.9691 lr=0.000510 elapsed=43.6s
# [train] step=75 ctc=9.7985 lr=0.000760 elapsed=62.6s
# [train] step=100 ctc=8.4387 lr=0.001010 elapsed=81.4s
# [val] step=100 20ms_ctc=9.9834 20ms_per=0.8694 40ms_ctc=10.0056 40ms_per=0.8653
# [train] step=125 ctc=7.8476 lr=0.001260 elapsed=114.9s
# [train] step=150 ctc=7.9984 lr=0.001510 elapsed=135.0s
# [train] step=175 ctc=7.0526 lr=0.001760 elapsed=154.1s
# [train] step=200 ctc=7.0905 lr=0.002010 elapsed=172.9s
# [val] step=200 20ms_ctc=8.5071 20ms_per=0.8726 40ms_ctc=8.4997 40ms_per=0.8667
# [train] step=225 ctc=6.9488 lr=0.002260 elapsed=200.4s
# [train] step=250 ctc=8.2796 lr=0.002510 elapsed=220.0s
# [train] step=275 ctc=7.6220 lr=0.002760 elapsed=238.1s
# [train] step=300 ctc=7.2074 lr=0.003010 elapsed=257.5s
# [val] step=300 20ms_ctc=7.8829 20ms_per=0.8562 40ms_ctc=7.8811 40ms_per=0.8487
# [train] step=325 ctc=9.3172 lr=0.003260 elapsed=283.1s
# [train] step=350 ctc=6.2389 lr=0.003510 elapsed=302.8s
# [train] step=375 ctc=6.7444 lr=0.003760 elapsed=323.9s
# [train] step=400 ctc=8.5389 lr=0.004010 elapsed=342.9s
# [val] step=400 20ms_ctc=8.3220 20ms_per=0.8213 40ms_ctc=8.3158 40ms_per=0.8217
# [train] step=425 ctc=5.9396 lr=0.004260 elapsed=371.3s
# [train] step=450 ctc=9.1734 lr=0.004510 elapsed=389.8s
# [train] step=475 ctc=8.9849 lr=0.004760 elapsed=407.6s
# [train] step=500 ctc=6.8504 lr=0.005010 elapsed=426.0s
# [val] step=500 20ms_ctc=8.4983 20ms_per=0.8412 40ms_ctc=8.5086 40ms_per=0.8399
# [train] step=525 ctc=8.1063 lr=0.005260 elapsed=452.9s
# [train] step=550 ctc=8.5434 lr=0.005510 elapsed=473.8s
# [train] step=575 ctc=6.6770 lr=0.005760 elapsed=496.0s
# [train] step=600 ctc=8.6912 lr=0.006010 elapsed=513.7s
# [val] step=600 20ms_ctc=8.6194 20ms_per=0.8264 40ms_ctc=8.6098 40ms_per=0.8249
# [train] step=625 ctc=6.9127 lr=0.006260 elapsed=541.7s
# [train] step=650 ctc=8.2156 lr=0.006510 elapsed=562.1s
# [train] step=675 ctc=6.4058 lr=0.006760 elapsed=582.1s
# [train] step=700 ctc=7.2126 lr=0.007010 elapsed=601.2s
# [val] step=700 20ms_ctc=9.5595 20ms_per=0.8439 40ms_ctc=9.5716 40ms_per=0.8443
# [train] step=725 ctc=7.0080 lr=0.007260 elapsed=629.0s
# [train] step=750 ctc=8.1895 lr=0.007510 elapsed=647.2s
# [train] step=775 ctc=8.3771 lr=0.007760 elapsed=667.3s
# [train] step=800 ctc=6.2942 lr=0.008010 elapsed=685.8s
# [val] step=800 20ms_ctc=8.2926 20ms_per=0.8228 40ms_ctc=8.2536 40ms_per=0.8195
# [train] step=825 ctc=6.1968 lr=0.008260 elapsed=713.4s
# [train] step=850 ctc=7.3141 lr=0.008510 elapsed=732.1s
# [train] step=875 ctc=6.9009 lr=0.008760 elapsed=752.6s
# [train] step=900 ctc=6.8614 lr=0.009010 elapsed=772.4s
# [val] step=900 20ms_ctc=8.8539 20ms_per=0.8347 40ms_ctc=8.8670 40ms_per=0.8339
# [train] step=925 ctc=8.6481 lr=0.009260 elapsed=797.7s
# [train] step=950 ctc=14.0241 lr=0.009510 elapsed=815.7s
# [train] step=975 ctc=7.1497 lr=0.009760 elapsed=834.7s
# [train] step=1000 ctc=6.6104 lr=0.010000 elapsed=853.7s
# [val] step=1000 20ms_ctc=6.8938 20ms_per=0.8096 40ms_ctc=6.8993 40ms_per=0.8094
# [train] step=1025 ctc=6.0059 lr=0.010000 elapsed=882.1s
# [train] step=1050 ctc=6.0444 lr=0.009999 elapsed=903.9s
# [train] step=1075 ctc=8.6707 lr=0.009998 elapsed=922.3s
# [train] step=1100 ctc=6.8081 lr=0.009997 elapsed=942.0s
# [val] step=1100 20ms_ctc=7.6749 20ms_per=0.8277 40ms_ctc=7.6780 40ms_per=0.8276
# [train] step=1125 ctc=7.8118 lr=0.009995 elapsed=968.8s
# [train] step=1150 ctc=9.4181 lr=0.009993 elapsed=988.5s
# [train] step=1175 ctc=5.8583 lr=0.009991 elapsed=1008.8s
# [train] step=1200 ctc=6.8188 lr=0.009988 elapsed=1028.6s
# [val] step=1200 20ms_ctc=6.8819 20ms_per=0.8156 40ms_ctc=6.8786 40ms_per=0.8143
# [train] step=1225 ctc=6.0883 lr=0.009985 elapsed=1055.1s
# [train] step=1250 ctc=6.0897 lr=0.009981 elapsed=1073.8s
# [train] step=1275 ctc=6.0955 lr=0.009977 elapsed=1092.7s
# [train] step=1300 ctc=5.5471 lr=0.009973 elapsed=1111.4s
# [val] step=1300 20ms_ctc=6.5774 20ms_per=0.7997 40ms_ctc=6.5561 40ms_per=0.7984
# [train] step=1325 ctc=5.7045 lr=0.009968 elapsed=1139.3s
# [train] step=1350 ctc=6.2256 lr=0.009963 elapsed=1160.2s
# [train] step=1375 ctc=5.6598 lr=0.009958 elapsed=1179.2s
# [train] step=1400 ctc=5.6451 lr=0.009952 elapsed=1199.6s
# [val] step=1400 20ms_ctc=6.6092 20ms_per=0.8031 40ms_ctc=6.6076 40ms_per=0.8016
# [train] step=1425 ctc=5.8526 lr=0.009946 elapsed=1226.4s
# [train] step=1450 ctc=5.4031 lr=0.009939 elapsed=1245.3s
# [train] step=1475 ctc=5.4705 lr=0.009932 elapsed=1264.1s
# [train] step=1500 ctc=5.5275 lr=0.009925 elapsed=1284.3s
# [val] step=1500 20ms_ctc=6.0715 20ms_per=0.7876 40ms_ctc=6.0441 40ms_per=0.7844
# [train] step=1525 ctc=6.1602 lr=0.009917 elapsed=1313.0s
# [train] step=1550 ctc=6.0928 lr=0.009909 elapsed=1331.6s
# [train] step=1575 ctc=7.0692 lr=0.009901 elapsed=1350.3s
# [train] step=1600 ctc=5.8879 lr=0.009892 elapsed=1369.4s
# [val] step=1600 20ms_ctc=6.0424 20ms_per=0.7846 40ms_ctc=6.0528 40ms_per=0.7840
# [train] step=1625 ctc=6.2970 lr=0.009883 elapsed=1397.5s
# [train] step=1650 ctc=5.8611 lr=0.009873 elapsed=1418.7s
# [train] step=1675 ctc=5.9716 lr=0.009863 elapsed=1439.2s
# [train] step=1700 ctc=5.4198 lr=0.009853 elapsed=1460.2s
# [val] step=1700 20ms_ctc=5.6870 20ms_per=0.7786 40ms_ctc=5.6571 40ms_per=0.7770
# [train] step=1725 ctc=5.2932 lr=0.009842 elapsed=1487.1s
# [train] step=1750 ctc=5.3122 lr=0.009831 elapsed=1506.9s
# [train] step=1775 ctc=5.2742 lr=0.009820 elapsed=1526.4s
# [train] step=1800 ctc=7.1651 lr=0.009808 elapsed=1548.3s
# [val] step=1800 20ms_ctc=6.0117 20ms_per=0.7872 40ms_ctc=6.0060 40ms_per=0.7854
# [train] step=1825 ctc=5.3229 lr=0.009796 elapsed=1575.5s
# [train] step=1850 ctc=5.2207 lr=0.009784 elapsed=1594.2s
# [train] step=1875 ctc=5.2299 lr=0.009771 elapsed=1614.6s
# [train] step=1900 ctc=5.5582 lr=0.009758 elapsed=1634.9s
# [val] step=1900 20ms_ctc=5.9534 20ms_per=0.7914 40ms_ctc=5.9424 40ms_per=0.7905
# [train] step=1925 ctc=5.6414 lr=0.009744 elapsed=1660.7s
# [train] step=1950 ctc=5.7035 lr=0.009730 elapsed=1679.4s
# [train] step=1975 ctc=5.9837 lr=0.009716 elapsed=1696.3s
# [train] step=2000 ctc=5.2414 lr=0.009701 elapsed=1715.0s
# [val] step=2000 20ms_ctc=5.5315 20ms_per=0.7697 40ms_ctc=5.5220 40ms_per=0.7682
# [train] step=2025 ctc=5.8553 lr=0.009687 elapsed=1742.6s
# [train] step=2050 ctc=6.0076 lr=0.009671 elapsed=1760.4s
# [train] step=2075 ctc=5.4159 lr=0.009656 elapsed=1779.4s
# [train] step=2100 ctc=5.6670 lr=0.009640 elapsed=1799.1s
# [val] step=2100 20ms_ctc=6.0842 20ms_per=0.7769 40ms_ctc=6.0615 40ms_per=0.7767
# [train] step=2125 ctc=5.1155 lr=0.009623 elapsed=1825.8s
# [train] step=2150 ctc=5.8541 lr=0.009606 elapsed=1844.3s
# [train] step=2175 ctc=5.0717 lr=0.009589 elapsed=1862.7s
# [train] step=2200 ctc=5.3213 lr=0.009572 elapsed=1883.2s
# [val] step=2200 20ms_ctc=5.2421 20ms_per=0.7640 40ms_ctc=5.2404 40ms_per=0.7637
# [train] step=2225 ctc=5.1589 lr=0.009554 elapsed=1909.0s
# [train] step=2250 ctc=5.1188 lr=0.009536 elapsed=1929.6s
# [train] step=2275 ctc=5.0716 lr=0.009518 elapsed=1949.7s
# [train] step=2300 ctc=5.1758 lr=0.009499 elapsed=1967.9s
# [val] step=2300 20ms_ctc=5.6141 20ms_per=0.7587 40ms_ctc=5.5864 40ms_per=0.7563
# [train] step=2325 ctc=5.1379 lr=0.009480 elapsed=1994.4s
# [train] step=2350 ctc=4.7381 lr=0.009460 elapsed=2015.8s
# [train] step=2375 ctc=4.8386 lr=0.009441 elapsed=2035.1s
# [train] step=2400 ctc=5.0132 lr=0.009421 elapsed=2056.1s
# [val] step=2400 20ms_ctc=5.0156 20ms_per=0.7571 40ms_ctc=5.0141 40ms_per=0.7569
# [train] step=2425 ctc=5.1623 lr=0.009400 elapsed=2084.9s
# [train] step=2450 ctc=4.8494 lr=0.009379 elapsed=2103.6s
# [train] step=2475 ctc=4.9007 lr=0.009358 elapsed=2125.8s
# [train] step=2500 ctc=4.8219 lr=0.009337 elapsed=2144.9s
# [val] step=2500 20ms_ctc=4.9058 20ms_per=0.7432 40ms_ctc=4.9079 40ms_per=0.7439
# [train] step=2525 ctc=5.4914 lr=0.009315 elapsed=2172.5s
# [train] step=2550 ctc=5.1810 lr=0.009293 elapsed=2192.5s
# [train] step=2575 ctc=4.9727 lr=0.009271 elapsed=2211.5s
# [train] step=2600 ctc=4.6924 lr=0.009248 elapsed=2230.7s
# [val] step=2600 20ms_ctc=5.2087 20ms_per=0.7660 40ms_ctc=5.2139 40ms_per=0.7665
# [train] step=2625 ctc=5.3743 lr=0.009225 elapsed=2259.2s
# [train] step=2650 ctc=4.5692 lr=0.009201 elapsed=2278.9s
# [train] step=2675 ctc=4.5928 lr=0.009178 elapsed=2299.5s
# [train] step=2700 ctc=4.9227 lr=0.009154 elapsed=2320.5s
# [val] step=2700 20ms_ctc=4.7789 20ms_per=0.7326 40ms_ctc=4.7733 40ms_per=0.7308
# [train] step=2725 ctc=5.3296 lr=0.009129 elapsed=2348.2s
# [train] step=2750 ctc=5.0901 lr=0.009105 elapsed=2367.5s
# [train] step=2775 ctc=4.8603 lr=0.009080 elapsed=2387.4s
# [train] step=2800 ctc=4.8813 lr=0.009055 elapsed=2408.8s
# [val] step=2800 20ms_ctc=5.3664 20ms_per=0.7576 40ms_ctc=5.3698 40ms_per=0.7561
# [train] step=2825 ctc=4.8929 lr=0.009029 elapsed=2434.4s
# [train] step=2850 ctc=4.9450 lr=0.009003 elapsed=2455.4s
# [train] step=2875 ctc=4.5832 lr=0.008977 elapsed=2474.3s
# [train] step=2900 ctc=4.6738 lr=0.008951 elapsed=2496.2s
# [val] step=2900 20ms_ctc=4.6021 20ms_per=0.7452 40ms_ctc=4.6023 40ms_per=0.7436
# [train] step=2925 ctc=4.8726 lr=0.008924 elapsed=2523.2s
# [train] step=2950 ctc=4.6903 lr=0.008897 elapsed=2543.0s
# [train] step=2975 ctc=4.8717 lr=0.008870 elapsed=2563.4s
# [train] step=3000 ctc=4.6703 lr=0.008842 elapsed=2584.8s
# [val] step=3000 20ms_ctc=4.8626 20ms_per=0.7379 40ms_ctc=4.8691 40ms_per=0.7381
# [train] step=3025 ctc=4.7847 lr=0.008814 elapsed=2613.1s
# [train] step=3050 ctc=4.2451 lr=0.008786 elapsed=2631.1s
# [train] step=3075 ctc=4.5301 lr=0.008757 elapsed=2650.0s
# [train] step=3100 ctc=4.5213 lr=0.008729 elapsed=2670.4s
# [val] step=3100 20ms_ctc=4.4509 20ms_per=0.7176 40ms_ctc=4.4465 40ms_per=0.7175
# [train] step=3125 ctc=4.4691 lr=0.008700 elapsed=2696.4s
# [train] step=3150 ctc=4.6774 lr=0.008670 elapsed=2714.9s
# [train] step=3175 ctc=4.2476 lr=0.008641 elapsed=2733.8s
# [train] step=3200 ctc=4.8436 lr=0.008611 elapsed=2753.2s
# [val] step=3200 20ms_ctc=4.4805 20ms_per=0.7248 40ms_ctc=4.4756 40ms_per=0.7233
# [train] step=3225 ctc=4.6345 lr=0.008581 elapsed=2779.8s
# [train] step=3250 ctc=5.4368 lr=0.008550 elapsed=2797.9s
# [train] step=3275 ctc=4.4302 lr=0.008520 elapsed=2817.7s
# [train] step=3300 ctc=4.6407 lr=0.008489 elapsed=2839.4s
# [val] step=3300 20ms_ctc=4.4107 20ms_per=0.7137 40ms_ctc=4.4116 40ms_per=0.7122
# ...
#             [
#               28,
#               794
#             ],
#             [
#               9,
#               757
#             ],
#             [
#               21,
#               729
#             ],
#             [
#               18,
#               670
#             ]
#           ],
#           "prediction_top_ids": [
#             [
#               40,
#               5393
#             ],
#             [
#               23,
#               1146
#             ],
#             [
#               31,
#               987
#             ],
#             [
#               3,
#               885
#             ],
#             [
#               22,
#               502
#             ],
#             [
#               2,
#               450
#             ],
#             [
#               17,
#               435
#             ],
#             [
#               34,
#               431
#             ],
#             [
#               21,
#               383
#             ],
#             [
#               10,
#               341
#             ]
#           ]
#         }
#       },
#       "40": {
#         "val_ctc_bpphone": 3.0789212630896263,
#         "val_phoneme_error_rate": 0.5907195640506956,
#         "active_bin_size_ms": 40,
#         "dt_scale": 1.0,
#         "active_patch_size_bins": 7,
#         "active_patch_stride_bins": 2,
#         "edit_diagnostics": {
#           "insertions": 87,
#           "deletions": 10333,
#           "substitutions": 3889
#         },
#         "collapse_diagnostics": {
#           "total_reference_tokens": 24223,
#           "total_predicted_tokens": 13977,
#           "predicted_to_reference_token_ratio": 0.5770135821326838,
#           "blank_frame_rate": 0.4706628856126718,
#           "reference_top_ids": [
#             [
#               40,
#               5498
#             ],
#             [
#               3,
#               1621
#             ],
#             [
#               31,
#               1585
#             ],
#             [
#               23,
#               1224
#             ],
#             [
#               17,
#               1130
#             ],
#             [
#               29,
#               877
#             ],
#             [
#               28,
#               794
#             ],
#             [
#               9,
#               757
#             ],
#             [
#               21,
#               729
#             ],
#             [
#               18,
#               670
#             ]
#           ],
#           "prediction_top_ids": [
#             [
#               40,
#               5372
#             ],
#             [
#               23,
#               1150
#             ],
#             [
#               31,
#               956
#             ],
#             [
#               3,
#               812
#             ],
#             [
#               22,
#               508
#             ],
#             [
#               2,
#               454
#             ],
#             [
#               34,
#               434
#             ],
#             [
#               17,
#               412
#             ],
#             [
#               21,
#               400
#             ],
#             [
#               20,
#               346
#             ]
#           ]
#         }
#       }
#     },
#     "val_20ms_ctc_bpphone": 3.072997872455074,
#     "val_20ms_phoneme_error_rate": 0.5893159393964414,
#     "val_40ms_ctc_bpphone": 3.0789212630896263,
#     "val_40ms_phoneme_error_rate": 0.5907195640506956
#   },
#   "best_progress_payload": {
#     "event": "timestep_flexible_val_report",
#     "step": 9600,
#     "selection_bin_size_ms": 20,
#     "best_val_phoneme_error_rate": 0.5893159393964414,
#     "metrics_by_bin_ms": {
#       "20": {
#         "val_ctc_bpphone": 3.072997872455074,
#         "val_phoneme_error_rate": 0.5893159393964414,
#         "active_bin_size_ms": 20,
#         "dt_scale": 1.0,
#         "active_patch_size_bins": 14,
#         "active_patch_stride_bins": 4,
#         "edit_diagnostics": {
#           "insertions": 88,
#           "deletions": 10186,
#           "substitutions": 4001
#         },
#         "collapse_diagnostics": {
#           "total_reference_tokens": 24223,
#           "total_predicted_tokens": 14125,
#           "predicted_to_reference_token_ratio": 0.5831234776864963,
#           "blank_frame_rate": 0.46876713616494586,
#           "reference_top_ids": [
#             [
#               40,
#               5498
#             ],
#             [
#               3,
#               1621
#             ],
#             [
#               31,
#               1585
#             ],
#             [
#               23,
#               1224
#             ],
#             [
#               17,
#               1130
#             ],
#             [
#               29,
#               877
#             ],
#             [
#               28,
#               794
#             ],
#             [
#               9,
#               757
#             ],
#             [
#               21,
#               729
#             ],
#             [
#               18,
#               670
#             ]
#           ],
#           "prediction_top_ids": [
#             [
#               40,
#               5393
#             ],
#             [
#               23,
#               1146
#             ],
#             [
#               31,
#               987
#             ],
#             [
#               3,
#               885
#             ],
#             [
#               22,
#               502
#             ],
#             [
#               2,
#               450
#             ],
#             [
#               17,
#               435
#             ],
#             [
#               34,
#               431
#             ],
#             [
#               21,
#               383
#             ],
#             [
#               10,
#               341
#             ]
#           ]
#         }
#       },
#       "40": {
#         "val_ctc_bpphone": 3.0789212630896263,
#         "val_phoneme_error_rate": 0.5907195640506956,
#         "active_bin_size_ms": 40,
#         "dt_scale": 1.0,
#         "active_patch_size_bins": 7,
#         "active_patch_stride_bins": 2,
#         "edit_diagnostics": {
#           "insertions": 87,
#           "deletions": 10333,
#           "substitutions": 3889
#         },
#         "collapse_diagnostics": {
#           "total_reference_tokens": 24223,
#           "total_predicted_tokens": 13977,
#           "predicted_to_reference_token_ratio": 0.5770135821326838,
#           "blank_frame_rate": 0.4706628856126718,
#           "reference_top_ids": [
#             [
#               40,
#               5498
#             ],
#             [
#               3,
#               1621
#             ],
#             [
#               31,
#               1585
#             ],
#             [
#               23,
#               1224
#             ],
#             [
#               17,
#               1130
#             ],
#             [
#               29,
#               877
#             ],
#             [
#               28,
#               794
#             ],
#             [
#               9,
#               757
#             ],
#             [
#               21,
#               729
#             ],
#             [
#               18,
#               670
#             ]
#           ],
#           "prediction_top_ids": [
#             [
#               40,
#               5372
#             ],
#             [
#               23,
#               1150
#             ],
#             [
#               31,
#               956
#             ],
#             [
#               3,
#               812
#             ],
#             [
#               22,
#               508
#             ],
#             [
#               2,
#               454
#             ],
#             [
#               34,
#               434
#             ],
#             [
#               17,
#               412
#             ],
#             [
#               21,
#               400
#             ],
#             [
#               20,
#               346
#             ]
#           ]
#         }
#       }
#     },
#     "val_20ms_ctc_bpphone": 3.072997872455074,
#     "val_20ms_phoneme_error_rate": 0.5893159393964414,
#     "val_40ms_ctc_bpphone": 3.0789212630896263,
#     "val_40ms_phoneme_error_rate": 0.5907195640506956,
#     "elapsed_seconds": 8199.68387746811
#   },
#   "progress_log_path": "/content/drive/MyDrive/utah_ssl/outputs/timestep_flexible_ssm/timestep_flexible_s5_tx_only_colab/progress.jsonl",
#   "summary_path": "/content/drive/MyDrive/utah_ssl/outputs/timestep_flexible_ssm/timestep_flexible_s5_tx_only_colab/summary.json",
#   "checkpoint_best_path": "/content/drive/MyDrive/utah_ssl/outputs/timestep_flexible_ssm/timestep_flexible_s5_tx_only_colab/checkpoint_best.pt",
#   "checkpoint_final_path": "/content/drive/MyDrive/utah_ssl/outputs/timestep_flexible_ssm/timestep_flexible_s5_tx_only_colab/checkpoint_final.pt",
#   "train_precomputed_split_stats_path": "/content/drive/MyDrive/utah_ssl/data/stats/split_feature_stats/raw/brain2text24/competition_train/tx_only/global_v1.pt",
#   "train_precomputed_split_stats_metadata": {
#     "kind": "split_feature_stats",
#     "created_utc": "2026-06-17T10:32:13Z",
#     "source_cache_root": "/content/drive/MyDrive/utah_ssl/data/cache_v1",
#     "source_cache_name": "cache_v1",
#     "source_cache_variant": "raw",
#     "source_cache_signature": "9a27f1dde5d6134484063311955284b6f9d72efd7c5fc4f1e86a2a0baf3e2b03",
#     "dataset": "brain2text24",
#     "feature_mode": "tx_only",
#     "boundary_key_mode": "session",
#     "split_policy": "competition_train_test",
#     "train_split_name": "competition_train",
#     "val_split_name": "competition_test",
#     "train_examples": 8800,
#     "val_examples": 880,
#     "train_session_ids": [
#       "t12.2022.04.28",
#       "t12.2022.05.05",
#       "t12.2022.05.17",
#       "t12.2022.05.19",
#       "t12.2022.05.24",
#       "t12.2022.05.26",
#       "t12.2022.06.02",
#       "t12.2022.06.07",
#       "t12.2022.06.14",
#       "t12.2022.06.16",
#       "t12.2022.06.21",
#       "t12.2022.06.23",
#       "t12.2022.06.28",
#       "t12.2022.07.05",
#       "t12.2022.07.14",
#       "t12.2022.07.21",
#       "t12.2022.07.27",
#       "t12.2022.07.29",
#       "t12.2022.08.02",
#       "t12.2022.08.11",
#       "t12.2022.08.13",
#       "t12.2022.08.18",
#       "t12.2022.08.23",
#       "t12.2022.08.25"
#     ],
#     "val_session_ids": [
#       "t12.2022.04.28",
#       "t12.2022.05.05",
#       "t12.2022.05.17",
#       "t12.2022.05.19",
#       "t12.2022.05.24",
#       "t12.2022.05.26",
#       "t12.2022.06.02",
#       "t12.2022.06.07",
#       "t12.2022.06.14",
#       "t12.2022.06.16",
#       "t12.2022.06.21",
#       "t12.2022.06.23",
#       "t12.2022.06.28",
#       "t12.2022.07.05",
#       "t12.2022.07.14",
#       "t12.2022.07.21",
#       "t12.2022.07.27",
#       "t12.2022.07.29",
#       "t12.2022.08.02",
#       "t12.2022.08.11",
#       "t12.2022.08.13",
#       "t12.2022.08.18",
#       "t12.2022.08.23",
#       "t12.2022.08.25"
#     ],
#     "feature_dim": 128,
#     "feature_policy": "area6v_v1"
#   },
#   "val_stats_metadata_by_bin_ms": {
#     "20": {
#       "kind": "split_feature_stats",
#       "created_utc": "2026-06-17T10:32:13Z",
#       "source_cache_root": "/content/drive/MyDrive/utah_ssl/data/cache_v1",
#       "source_cache_name": "cache_v1",
#       "source_cache_variant": "raw",
#       "source_cache_signature": "9a27f1dde5d6134484063311955284b6f9d72efd7c5fc4f1e86a2a0baf3e2b03",
#       "dataset": "brain2text24",
#       "feature_mode": "tx_only",
#       "boundary_key_mode": "session",
#       "split_policy": "competition_train_test",
#       "train_split_name": "competition_train",
#       "val_split_name": "competition_test",
#       "train_examples": 8800,
#       "val_examples": 880,
#       "train_session_ids": [
#         "t12.2022.04.28",
#         "t12.2022.05.05",
#         "t12.2022.05.17",
#         "t12.2022.05.19",
#         "t12.2022.05.24",
#         "t12.2022.05.26",
#         "t12.2022.06.02",
#         "t12.2022.06.07",
#         "t12.2022.06.14",
#         "t12.2022.06.16",
#         "t12.2022.06.21",
#         "t12.2022.06.23",
#         "t12.2022.06.28",
#         "t12.2022.07.05",
#         "t12.2022.07.14",
#         "t12.2022.07.21",
#         "t12.2022.07.27",
#         "t12.2022.07.29",
#         "t12.2022.08.02",
#         "t12.2022.08.11",
#         "t12.2022.08.13",
#         "t12.2022.08.18",
#         "t12.2022.08.23",
#         "t12.2022.08.25"
#       ],
#       "val_session_ids": [
#         "t12.2022.04.28",
#         "t12.2022.05.05",
#         "t12.2022.05.17",
#         "t12.2022.05.19",
#         "t12.2022.05.24",
#         "t12.2022.05.26",
#         "t12.2022.06.02",
#         "t12.2022.06.07",
#         "t12.2022.06.14",
#         "t12.2022.06.16",
#         "t12.2022.06.21",
#         "t12.2022.06.23",
#         "t12.2022.06.28",
#         "t12.2022.07.05",
#         "t12.2022.07.14",
#         "t12.2022.07.21",
#         "t12.2022.07.27",
#         "t12.2022.07.29",
#         "t12.2022.08.02",
#         "t12.2022.08.11",
#         "t12.2022.08.13",
#         "t12.2022.08.18",
#         "t12.2022.08.23",
#         "t12.2022.08.25"
#       ],
#       "feature_dim": 128,
#       "feature_policy": "area6v_v1"
#     },
#     "40": null
#   },
#   "val_stats_path_by_bin_ms": {
#     "20": "/content/drive/MyDrive/utah_ssl/data/stats/split_feature_stats/raw/brain2text24/competition_train/tx_only/global_v1.pt",
#     "40": null
#   },
#   "trainable_parameters": 10573870,
#   "device": "cuda"
# }
# {'event': 'timestep_flexible_train_report', 'step': 9925, 'train_ctc_bpphone': 3.5330196534453466, 'train_bin_size_ms': 20, 'optimizer_target_examples': 64, 'accumulated_examples': 120, 'accumulation_microbatches': 2, 'train_boundary_key': 'brain2text24:t12.2022.04.28', 'learning_rate': 0.00010169624137099158, 'elapsed_seconds': 8473.790091514587}
# {'event': 'timestep_flexible_train_report', 'step': 9950, 'train_ctc_bpphone': 2.9238779335032294, 'train_bin_size_ms': 20, 'optimizer_target_examples': 64, 'accumulated_examples': 100, 'accumulation_microbatches': 2, 'train_boundary_key': 'brain2text24:t12.2022.06.21', 'learning_rate': 0.00010075390897586321, 'elapsed_seconds': 8492.814204454422}
# {'event': 'timestep_flexible_train_report', 'step': 9975, 'train_ctc_bpphone': 3.2593353070389974, 'train_bin_size_ms': 20, 'optimizer_target_examples': 64, 'accumulated_examples': 116, 'accumulation_microbatches': 2, 'train_boundary_key': 'brain2text24:t12.2022.08.02', 'learning_rate': 0.00010018848083235203, 'elapsed_seconds': 8512.54556798935}
# {'event': 'timestep_flexible_train_report', 'step': 10000, 'train_ctc_bpphone': 3.2202031828010083, 'train_bin_size_ms': 20, 'optimizer_target_examples': 64, 'accumulated_examples': 92, 'accumulation_microbatches': 2, 'train_boundary_key': 'brain2text24:t12.2022.06.28', 'learning_rate': 0.0001, 'elapsed_seconds': 8530.729763269424}
# {'event': 'timestep_flexible_val_report', 'step': 10000, 'selection_bin_size_ms': 20, 'best_val_phoneme_error_rate': 0.5893159393964414, 'metrics_by_bin_ms': {'20': {'val_ctc_bpphone': 3.0698281717789007, 'val_phoneme_error_rate': 0.5902654501919663, 'active_bin_size_ms': 20, 'dt_scale': 1.0, 'active_patch_size_bins': 14, 'active_patch_stride_bins': 4, 'edit_diagnostics': {'insertions': 94, 'deletions': 10252, 'substitutions': 3952}, 'collapse_diagnostics': {'total_reference_tokens': 24223, 'total_predicted_tokens': 14065, 'predicted_to_reference_token_ratio': 0.5806464930025182, 'blank_frame_rate': 0.4699265201247121, 'reference_top_ids': [[40, 5498], [3, 1621], [31, 1585], [23, 1224], [17, 1130], [29, 877], [28, 794], [9, 757], [21, 729], [18, 670]], 'prediction_top_ids': [[40, 5387], [23, 1124], [31, 975], [3, 874], [22, 490], [17, 468], [2, 435], [34, 429], [21, 393], [35, 335]]}}, '40': {'val_ctc_bpphone': 3.0758215833715634, 'val_phoneme_error_rate': 0.5906782809726293, 'active_bin_size_ms': 40, 'dt_scale': 1.0, 'active_patch_size_bins': 7, 'active_patch_stride_bins': 2, 'edit_diagnostics': {'insertions': 82, 'deletions': 10371, 'substitutions': 3855}, 'collapse_diagnostics': {'total_reference_tokens': 24223, 'total_predicted_tokens': 13934, 'predicted_to_reference_token_ratio': 0.5752384097758328, 'blank_frame_rate': 0.4727309759192818, 'reference_top_ids': [[40, 5498], [3, 1621], [31, 1585], [23, 1224], [17, 1130], [29, 877], [28, 794], [9, 757], [21, 729], [18, 670]], 'prediction_top_ids': [[40, 5374], [23, 1132], [31, 958], [3, 806], [22, 498], [2, 438], [17, 436], [34, 436], [21, 406], [20, 342]]}}}, 'val_20ms_ctc_bpphone': 3.0698281717789007, 'val_20ms_phoneme_error_rate': 0.5902654501919663, 'val_40ms_ctc_bpphone': 3.0758215833715634, 'val_40ms_phoneme_error_rate': 0.5906782809726293, 'elapsed_seconds': 8537.703460931778}

# %%
MAX_STEPS = 10000

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

summary_path = RUN_DIR / 'summary.json'
progress_path = RUN_DIR / 'progress.jsonl'
summary = json.loads(summary_path.read_text())
progress = [json.loads(line) for line in progress_path.read_text().splitlines() if line.strip()]
progress_df = pd.DataFrame(progress)
train_df = progress_df[progress_df['event'] == 'timestep_flexible_train_report'].copy()
val_df = progress_df[progress_df['event'] == 'timestep_flexible_val_report'].copy()

fig, axes = plt.subplots(1, 2, figsize=(13, 4.5))
if not train_df.empty:
    axes[0].plot(train_df['step'], train_df['train_ctc_bpphone'], label='train CTC')
if not val_df.empty:
    if 'val_20ms_ctc_bpphone' in val_df:
        axes[0].plot(val_df['step'], val_df['val_20ms_ctc_bpphone'], marker='o', label='val 20 ms CTC')
    if 'val_40ms_ctc_bpphone' in val_df:
        axes[0].plot(val_df['step'], val_df['val_40ms_ctc_bpphone'], marker='o', label='val 40 ms CTC')
    if 'val_20ms_phoneme_error_rate' in val_df:
        axes[1].plot(val_df['step'], val_df['val_20ms_phoneme_error_rate'], marker='o', label='val 20 ms PER')
    if 'val_40ms_phoneme_error_rate' in val_df:
        axes[1].plot(val_df['step'], val_df['val_40ms_phoneme_error_rate'], marker='o', label='val 40 ms PER')
axes[0].set_title('Timestep-Flexible S5 CTC')
axes[0].set_xlabel('step')
axes[0].set_ylabel('bits / phoneme')
axes[0].grid(True, alpha=0.3)
axes[0].legend()
axes[1].set_title('Timestep-Flexible S5 PER')
axes[1].set_xlabel('step')
axes[1].set_ylabel('PER')
axes[1].grid(True, alpha=0.3)
axes[1].legend()
plt.tight_layout()
plt.show()

print('best step:', summary.get('best_step'))
print('final metrics:', json.dumps(summary.get('metrics', {}), indent=2))
print('best metrics:', json.dumps(summary.get('best_metrics', {}), indent=2))
if not val_df.empty:
    columns = ['step']
    for name in [
        'val_20ms_ctc_bpphone',
        'val_40ms_ctc_bpphone',
        'val_20ms_phoneme_error_rate',
        'val_40ms_phoneme_error_rate',
    ]:
        if name in val_df.columns:
            columns.append(name)
    display(val_df[columns].tail(10))
# Out:
# best step: 9600
# final metrics: {
#   "selection_bin_size_ms": 20,
#   "best_val_phoneme_error_rate": 0.5893159393964414,
#   "metrics_by_bin_ms": {
#     "20": {
#       "val_ctc_bpphone": 3.0698281717789007,
#       "val_phoneme_error_rate": 0.5902654501919663,
#       "active_bin_size_ms": 20,
#       "dt_scale": 1.0,
#       "active_patch_size_bins": 14,
#       "active_patch_stride_bins": 4,
#       "edit_diagnostics": {
#         "insertions": 94,
#         "deletions": 10252,
#         "substitutions": 3952
#       },
#       "collapse_diagnostics": {
#         "total_reference_tokens": 24223,
#         "total_predicted_tokens": 14065,
#         "predicted_to_reference_token_ratio": 0.5806464930025182,
#         "blank_frame_rate": 0.4699265201247121,
#         "reference_top_ids": [
#           [
#             40,
#             5498
#           ],
#           [
#             3,
#             1621
#           ],
#           [
#             31,
#             1585
#           ],
#           [
#             23,
#             1224
#           ],
#           [
#             17,
#             1130
#           ],
#           [
#             29,
#             877
#           ],
#           [
#             28,
#             794
#           ],
#           [
#             9,
#             757
#           ],
#           [
#             21,
#             729
#           ],
#           [
#             18,
#             670
#           ]
#         ],
#         "prediction_top_ids": [
#           [
#             40,
#             5387
#           ],
#           [
#             23,
#             1124
#           ],
#           [
#             31,
#             975
#           ],
#           [
#             3,
#             874
#           ],
#           [
#             22,
#             490
#           ],
#           [
#             17,
#             468
#           ],
#           [
#             2,
#             435
#           ],
#           [
#             34,
#             429
#           ],
#           [
#             21,
#             393
#           ],
#           [
#             35,
#             335
#           ]
#         ]
#       }
#     },
#     "40": {
#       "val_ctc_bpphone": 3.0758215833715634,
#       "val_phoneme_error_rate": 0.5906782809726293,
#       "active_bin_size_ms": 40,
#       "dt_scale": 1.0,
#       "active_patch_size_bins": 7,
#       "active_patch_stride_bins": 2,
#       "edit_diagnostics": {
#         "insertions": 82,
#         "deletions": 10371,
#         "substitutions": 3855
#       },
#       "collapse_diagnostics": {
#         "total_reference_tokens": 24223,
#         "total_predicted_tokens": 13934,
#         "predicted_to_reference_token_ratio": 0.5752384097758328,
#         "blank_frame_rate": 0.4727309759192818,
#         "reference_top_ids": [
#           [
#             40,
#             5498
#           ],
#           [
#             3,
#             1621
#           ],
#           [
#             31,
#             1585
#           ],
#           [
#             23,
#             1224
#           ],
#           [
#             17,
#             1130
#           ],
#           [
#             29,
#             877
#           ],
#           [
#             28,
#             794
#           ],
#           [
#             9,
#             757
#           ],
#           [
#             21,
#             729
#           ],
#           [
#             18,
#             670
#           ]
#         ],
#         "prediction_top_ids": [
#           [
#             40,
#             5374
#           ],
#           [
#             23,
#             1132
#           ],
#           [
#             31,
#             958
#           ],
#           [
#             3,
#             806
#           ],
#           [
#             22,
#             498
#           ],
#           [
#             2,
#             438
#           ],
#           [
#             17,
#             436
#           ],
#           [
#             34,
#             436
#           ],
#           [
#             21,
#             406
#           ],
#           [
#             20,
#             342
#           ]
#         ]
#       }
#     }
#   },
#   "val_20ms_ctc_bpphone": 3.0698281717789007,
#   "val_20ms_phoneme_error_rate": 0.5902654501919663,
#   "val_40ms_ctc_bpphone": 3.0758215833715634,
#   "val_40ms_phoneme_error_rate": 0.5906782809726293
# }
# best metrics: {
#   "selection_bin_size_ms": 20,
#   "best_val_phoneme_error_rate": 0.5893159393964414,
#   "metrics_by_bin_ms": {
#     "20": {
#       "val_ctc_bpphone": 3.072997872455074,
#       "val_phoneme_error_rate": 0.5893159393964414,
#       "active_bin_size_ms": 20,
#       "dt_scale": 1.0,
#       "active_patch_size_bins": 14,
#       "active_patch_stride_bins": 4,
#       "edit_diagnostics": {
#         "insertions": 88,
#         "deletions": 10186,
#         "substitutions": 4001
#       },
#       "collapse_diagnostics": {
#         "total_reference_tokens": 24223,
#         "total_predicted_tokens": 14125,
#         "predicted_to_reference_token_ratio": 0.5831234776864963,
#         "blank_frame_rate": 0.46876713616494586,
#         "reference_top_ids": [
#           [
#             40,
#             5498
#           ],
#           [
#             3,
#             1621
#           ],
#           [
#             31,
#             1585
#           ],
#           [
#             23,
#             1224
#           ],
#           [
#             17,
#             1130
#           ],
#           [
#             29,
#             877
#           ],
#           [
#             28,
#             794
#           ],
#           [
#             9,
#             757
#           ],
#           [
#             21,
#             729
#           ],
#           [
#             18,
#             670
#           ]
#         ],
#         "prediction_top_ids": [
#           [
#             40,
#             5393
#           ],
#           [
#             23,
#             1146
#           ],
#           [
#             31,
#             987
#           ],
#           [
#             3,
#             885
#           ],
#           [
#             22,
#             502
#           ],
#           [
#             2,
#             450
#           ],
#           [
#             17,
#             435
#           ],
#           [
#             34,
#             431
#           ],
#           [
#             21,
#             383
#           ],
#           [
#             10,
#             341
#           ]
#         ]
#       }
#     },
#     "40": {
#       "val_ctc_bpphone": 3.0789212630896263,
#       "val_phoneme_error_rate": 0.5907195640506956,
#       "active_bin_size_ms": 40,
#       "dt_scale": 1.0,
#       "active_patch_size_bins": 7,
#       "active_patch_stride_bins": 2,
#       "edit_diagnostics": {
#         "insertions": 87,
#         "deletions": 10333,
#         "substitutions": 3889
#       },
#       "collapse_diagnostics": {
#         "total_reference_tokens": 24223,
#         "total_predicted_tokens": 13977,
#         "predicted_to_reference_token_ratio": 0.5770135821326838,
#         "blank_frame_rate": 0.4706628856126718,
#         "reference_top_ids": [
#           [
#             40,
#             5498
#           ],
#           [
#             3,
#             1621
#           ],
#           [
#             31,
#             1585
#           ],
#           [
#             23,
#             1224
#           ],
#           [
#             17,
#             1130
#           ],
#           [
#             29,
#             877
#           ],
#           [
#             28,
#             794
#           ],
#           [
#             9,
#             757
#           ],
#           [
#             21,
#             729
#           ],
#           [
#             18,
#             670
#           ]
#         ],
#         "prediction_top_ids": [
#           [
#             40,
#             5372
#           ],
#           [
#             23,
#             1150
#           ],
#           [
#             31,
#             956
#           ],
#           [
#             3,
#             812
#           ],
#           [
#             22,
#             508
#           ],
#           [
#             2,
#             454
#           ],
#           [
#             34,
#             434
#           ],
#           [
#             17,
#             412
#           ],
#           [
#             21,
#             400
#           ],
#           [
#             20,
#             346
#           ]
#         ]
#       }
#     }
#   },
#   "val_20ms_ctc_bpphone": 3.072997872455074,
#   "val_20ms_phoneme_error_rate": 0.5893159393964414,
#   "val_40ms_ctc_bpphone": 3.0789212630896263,
#   "val_40ms_phoneme_error_rate": 0.5907195640506956
# }
#        step  val_20ms_ctc_bpphone  val_40ms_ctc_bpphone  \
# 1056   9100              3.075404              3.081581
# 1061   9200              3.074929              3.080720
# 1066   9300              3.076143              3.082102
# 1071   9400              3.072652              3.078722
# 1076   9500              3.073095              3.079210
# 1081   9600              3.072998              3.078921
# 1086   9700              3.071669              3.077571
# 1091   9800              3.071954              3.077980
# 1096   9900              3.070912              3.076921
# 1101  10000              3.069828              3.075822
#
#       val_20ms_phoneme_error_rate  val_40ms_phoneme_error_rate
# 1056                     0.593279                     0.594311
# 1061                     0.592742                     0.594930
# 1066                     0.590513                     0.591793
# 1071                     0.590100                     0.591752
# 1076                     0.590265                     0.591793
# 1081                     0.589316                     0.590720
# 1086                     0.589522                     0.590802
# 1091                     0.589729                     0.590348
# 1096                     0.590183                     0.590596
# 1101                     0.590265                     0.590678

# %% [markdown]
# ## Willett GRU Baseline Check
#
# Validation-only comparison for the saved `willett_tx_only_area6v_colab` GRU checkpoint. This keeps patch duration / hop fixed in milliseconds and resamples `40 ms` patch tokens back to the checkpoint's original `14`-bin token width before the GRU forward pass.

# %%
import json
import sys
from pathlib import Path

import numpy as np
import pandas as pd
import torch
import torch.nn.functional as F
from IPython.display import display
from torch import nn
from torch.utils.data import DataLoader

if str(EXPERIMENTS_DIR) not in sys.path:
    sys.path.insert(0, str(EXPERIMENTS_DIR))

from utah_ssl.scripts.recompute_split_feature_stats import (
    load_precomputed_split_feature_stats,
    resolve_precomputed_split_stats_path,
)
from utah_ssl.ctc import compute_ctc_loss_sum, ctc_bits_per_target, ctc_greedy_decode, edit_counts
from utah_ssl.patching import patch_starts
from experiments.archive.timestep_flexible_ssm.data import (
    RebinnedSequenceDataset,
    TimestepFlexibleInputTransformConfig,
    build_timestep_flexible_problem,
    compute_rebinned_normalization_stats,
    loader_kwargs,
    make_length_aware_batch_sampler,
    prepare_timestep_flexible_inputs,
    resolve_patch_bins,
)
from experiments.supervised_baselines.data import adapter_keys_from_rows, normalization_stats_missing_rows
from experiments.supervised_baselines.model import WillettPhonemeModel

GRU_RUN_NAME = 'willett_tx_only_area6v_colab'
GRU_RUN_DIR = Path('/content/drive/MyDrive/utah_ssl/outputs/willett_reconstruction') / GRU_RUN_NAME
GRU_CHECKPOINT_PATH = GRU_RUN_DIR / 'checkpoint_best.pt'
GRU_SAVED_BEST_20MS_CTC = 1.8476455153996616
GRU_SAVED_BEST_20MS_PER = 0.3724146472360979
S5_SUMMARY_PATH = RUN_DIR / 'summary.json'

if not GRU_CHECKPOINT_PATH.exists():
    raise FileNotFoundError(
        f'Missing GRU checkpoint: {GRU_CHECKPOINT_PATH}. '
        'Mount Drive and confirm the Willett baseline run is present before running this cell.'
    )


def _feature_dim_from_problem(problem, feature_mode):
    row = problem['train_rows'][0]
    if feature_mode == 'tx_only':
        return int(row.n_tx_features)
    return int(row.n_tx_features + row.n_sbp_features)


def _extract_s5_metric(summary_dict, bin_size_ms, metric_name):
    best_metrics = summary_dict.get('best_metrics', {})
    key = f'val_{int(bin_size_ms)}ms_{metric_name}'
    if key in best_metrics:
        return float(best_metrics[key])
    by_bin = best_metrics.get('metrics_by_bin_ms', {})
    if str(int(bin_size_ms)) in by_bin and metric_name in by_bin[str(int(bin_size_ms))]:
        return float(by_bin[str(int(bin_size_ms))][metric_name])
    raise KeyError(f'Could not find {metric_name} for {bin_size_ms} ms in summary.json')


def _load_stats_for_bin(problem, checkpoint_cfg, sample_dim, bin_size_ms):
    normalization_mode = str(checkpoint_cfg.get('normalization_mode', 'global'))
    if int(bin_size_ms) == 20 and normalization_mode == 'global':
        stats_path = resolve_precomputed_split_stats_path(
            cache_root=Path(problem['cache_root']),
            dataset=str(problem['dataset']),
            train_split_name=str(problem['train_split_name']),
            feature_mode=str(problem['feature_mode']),
            preferred_path=checkpoint_cfg.get('precomputed_split_stats_path'),
        )
        if stats_path.exists():
            (mean_t, std_t), _, loaded_path = load_precomputed_split_feature_stats(
                stats_path=stats_path,
                cache_root=Path(problem['cache_root']),
                dataset=str(problem['dataset']),
                feature_mode=str(problem['feature_mode']),
                boundary_key_mode=str(problem['boundary_key_mode']),
                train_split_name=str(problem['train_split_name']),
                val_split_name=str(problem['val_split_name']),
                expected_dim=int(sample_dim),
            )
            print(f'Loaded canonical 20 ms split stats: {loaded_path}')
            return (
                mean_t.numpy().astype(np.float32, copy=False),
                std_t.numpy().astype(np.float32, copy=False),
            )
    print(f'Computing train-derived normalization stats for {bin_size_ms} ms bins...')
    return compute_rebinned_normalization_stats(
        problem['train_rows'],
        cache_root=Path(problem['cache_root']),
        feature_mode=str(problem['feature_mode']),
        mode=normalization_mode,
        bin_size_ms=int(bin_size_ms),
    )


def _resample_patch_width(patch_2d, target_bins):
    if int(patch_2d.shape[0]) == int(target_bins):
        return patch_2d
    patch_cf = patch_2d.transpose(0, 1).unsqueeze(0)
    resized = F.interpolate(
        patch_cf,
        size=int(target_bins),
        mode='linear',
        align_corners=False,
    )
    return resized.squeeze(0).transpose(0, 1)


def _patch_resample_batch(x, input_lengths, active_patch_size_bins, active_patch_stride_bins, reference_patch_size_bins):
    token_sequences = []
    token_lengths = []
    feature_dim = int(x.shape[-1])
    patch_dim = feature_dim * int(reference_patch_size_bins)
    for sample, length_tensor in zip(x, input_lengths):
        length = max(0, int(length_tensor.item()))
        starts = patch_starts(
            length,
            patch_size=int(active_patch_size_bins),
            patch_stride=int(active_patch_stride_bins),
            policy='floor',
        )
        if not starts:
            tokens = sample.new_zeros((0, patch_dim))
        else:
            valid = sample[:length]
            patches = []
            for start in starts:
                patch = valid[start : start + int(active_patch_size_bins)]
                if int(patch.shape[0]) < int(active_patch_size_bins):
                    pad = valid.new_zeros((int(active_patch_size_bins) - int(patch.shape[0]), feature_dim))
                    patch = torch.cat([patch, pad], dim=0)
                patch = _resample_patch_width(patch, int(reference_patch_size_bins))
                patches.append(patch.reshape(-1))
            tokens = torch.stack(patches, dim=0)
        token_sequences.append(tokens)
        token_lengths.append(int(tokens.shape[0]))
    max_tokens = max(token_lengths, default=0)
    patched = x.new_zeros((int(x.shape[0]), max_tokens, patch_dim))
    for batch_idx, tokens in enumerate(token_sequences):
        if int(tokens.shape[0]) > 0:
            patched[batch_idx, : int(tokens.shape[0])] = tokens
    return patched, torch.as_tensor(token_lengths, device=input_lengths.device, dtype=torch.long)


def _forward_willett_gru_resampled(model, x, input_lengths, boundary_keys, active_bin_size_ms, patch_size_ms, patch_stride_ms, reference_patch_size_bins):
    adapted_input = model.session_input_adapter(
        x,
        boundary_keys,
        session_adapter_enabled=model.session_adapter_enabled,
    )
    active_patch_size_bins = resolve_patch_bins(
        int(patch_size_ms),
        bin_size_ms=int(active_bin_size_ms),
        field_name='patch_size_ms',
    )
    active_patch_stride_bins = resolve_patch_bins(
        int(patch_stride_ms),
        bin_size_ms=int(active_bin_size_ms),
        field_name='patch_stride_ms',
    )
    patched_inputs, token_lengths = _patch_resample_batch(
        adapted_input,
        input_lengths,
        active_patch_size_bins=int(active_patch_size_bins),
        active_patch_stride_bins=int(active_patch_stride_bins),
        reference_patch_size_bins=int(reference_patch_size_bins),
    )
    if int((token_lengths <= 0).sum().item()) > 0:
        raise ValueError('Encountered zero-length token sequence during GRU evaluation; inspect rebinned cache rows.')
    packed = nn.utils.rnn.pack_padded_sequence(
        patched_inputs,
        token_lengths.cpu(),
        batch_first=True,
        enforce_sorted=False,
    )
    initial_hidden = model._initial_hidden_state(
        batch_size=int(x.shape[0]),
        device=patched_inputs.device,
        dtype=patched_inputs.dtype,
    )
    packed_hidden, _ = model.gru(packed, initial_hidden)
    hidden, _ = nn.utils.rnn.pad_packed_sequence(
        packed_hidden,
        batch_first=True,
        total_length=patched_inputs.shape[1],
    )
    logits = model.classifier(hidden)
    return {
        'adapted_input': adapted_input,
        'patched_inputs': patched_inputs,
        'hidden': hidden,
        'decoder_hidden': hidden,
        'token_lengths': token_lengths,
        'logits': logits,
        'active_patch_size_bins': int(active_patch_size_bins),
        'active_patch_stride_bins': int(active_patch_stride_bins),
    }


def _evaluate_willett_gru(model, loader, device, blank_index, input_transform_config, active_bin_size_ms, patch_size_ms, patch_stride_ms, reference_patch_size_bins):
    model.eval()
    total_loss_sum = 0.0
    total_target_count = 0
    total_insertions = 0
    total_deletions = 0
    total_substitutions = 0
    total_reference_tokens = 0
    with torch.no_grad():
        for batch in loader:
            x = batch['x'].to(device)
            input_lengths = batch['input_lengths'].to(device)
            labels = batch['labels'].to(device)
            label_lengths = batch['label_lengths'].to(device)
            x = prepare_timestep_flexible_inputs(
                x,
                input_lengths,
                config=input_transform_config,
                active_bin_size_ms=int(active_bin_size_ms),
                is_training=False,
            )
            outputs = _forward_willett_gru_resampled(
                model,
                x,
                input_lengths,
                batch['boundary_keys'],
                active_bin_size_ms=int(active_bin_size_ms),
                patch_size_ms=int(patch_size_ms),
                patch_stride_ms=int(patch_stride_ms),
                reference_patch_size_bins=int(reference_patch_size_bins),
            )
            loss_sum, target_count = compute_ctc_loss_sum(
                outputs['logits'],
                outputs['token_lengths'],
                labels,
                label_lengths,
                blank_index=int(blank_index),
            )
            if int(target_count) <= 0:
                continue
            total_loss_sum += float(loss_sum.item())
            total_target_count += int(target_count)
            predictions = ctc_greedy_decode(
                outputs['logits'],
                outputs['token_lengths'],
                blank_index=int(blank_index),
            )
            for row_idx, prediction in enumerate(predictions):
                reference = labels[row_idx, : int(label_lengths[row_idx].item())].tolist()
                insertions, deletions, substitutions = edit_counts(reference, prediction)
                total_insertions += int(insertions)
                total_deletions += int(deletions)
                total_substitutions += int(substitutions)
                total_reference_tokens += len(reference)
    if total_target_count <= 0 or total_reference_tokens <= 0:
        raise ValueError('Validation set produced zero effective targets during GRU evaluation.')
    total_errors = total_insertions + total_deletions + total_substitutions
    return {
        'val_ctc_bpphone': float(ctc_bits_per_target(total_loss_sum, total_target_count)),
        'val_phoneme_error_rate': float(total_errors / total_reference_tokens),
    }


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
try:
    payload = torch.load(GRU_CHECKPOINT_PATH, map_location='cpu', weights_only=False)
except TypeError:
    payload = torch.load(GRU_CHECKPOINT_PATH, map_location='cpu')
checkpoint_cfg = dict(payload['config'])
problem = build_timestep_flexible_problem(
    cache_root=CACHE_ROOT,
    dataset=checkpoint_cfg.get('dataset', DATASET),
    feature_mode=checkpoint_cfg.get('feature_mode', FEATURE_MODE),
    boundary_key_mode=checkpoint_cfg.get('boundary_key_mode', 'session'),
    split_policy=checkpoint_cfg.get('split_policy', 'competition_train_test'),
    cv_num_folds=int(checkpoint_cfg.get('cv_num_folds', 5)),
    cv_fold_index=int(checkpoint_cfg.get('cv_fold_index', 0)),
)
sample_dim = _feature_dim_from_problem(problem, str(problem['feature_mode']))
train_adapter_keys = adapter_keys_from_rows(
    problem['train_rows'],
    dataset=str(problem['dataset']),
    boundary_key_mode=str(problem['boundary_key_mode']),
)
val_adapter_keys = adapter_keys_from_rows(
    problem['val_rows'],
    dataset=str(problem['dataset']),
    boundary_key_mode=str(problem['boundary_key_mode']),
)
session_adapter_keys = tuple(dict.fromkeys([*train_adapter_keys, *val_adapter_keys]))
model = WillettPhonemeModel(
    input_dim=int(sample_dim),
    vocab_size=int(problem['vocab']['num_classes']),
    patch_size=int(checkpoint_cfg.get('patch_size', 14)),
    patch_stride=int(checkpoint_cfg.get('patch_stride', 4)),
    input_projection_size=int(checkpoint_cfg.get('input_projection_size', 256)),
    input_projection_dropout=float(checkpoint_cfg.get('input_projection_dropout', 0.2)),
    decoder_backbone_type=str(checkpoint_cfg.get('decoder_backbone_type', 'gru')),
    gru_hidden_size=int(checkpoint_cfg.get('gru_hidden_size', 512)),
    gru_num_layers=int(checkpoint_cfg.get('gru_num_layers', 5)),
    gru_dropout=float(checkpoint_cfg.get('gru_dropout', 0.4)),
    s5_hidden_size=int(checkpoint_cfg.get('s5_hidden_size', 512)),
    s5_state_size=int(checkpoint_cfg.get('s5_state_size', 128)),
    s5_num_layers=int(checkpoint_cfg.get('s5_num_layers', 5)),
    s5_dropout=float(checkpoint_cfg.get('s5_dropout', 0.2)),
    s5_direction=str(checkpoint_cfg.get('s5_direction', 'causal')),
    s5_ffn_multiplier=float(checkpoint_cfg.get('s5_ffn_multiplier', 2.0)),
    s4d_hidden_size=int(checkpoint_cfg.get('s4d_hidden_size', 512)),
    s4d_state_size=int(checkpoint_cfg.get('s4d_state_size', 128)),
    s4d_num_layers=int(checkpoint_cfg.get('s4d_num_layers', 5)),
    s4d_dropout=float(checkpoint_cfg.get('s4d_dropout', 0.2)),
    s4d_direction=str(checkpoint_cfg.get('s4d_direction', 'causal')),
    s4d_ffn_multiplier=float(checkpoint_cfg.get('s4d_ffn_multiplier', 2.0)),
    session_adapter_keys=session_adapter_keys,
    session_adapter_enabled=bool(checkpoint_cfg.get('session_adapter_enabled', True)),
)
missing_keys, unexpected_keys = model.load_state_dict(payload['model_state'], strict=False)
if missing_keys or unexpected_keys:
    raise RuntimeError(
        'GRU checkpoint/model mismatch. '
        f'missing_keys={missing_keys} unexpected_keys={unexpected_keys}'
    )
model = model.to(device)
if str(checkpoint_cfg.get('decoder_backbone_type', 'gru')) != 'gru':
    raise ValueError('Expected a GRU checkpoint for this notebook baseline cell.')

smoothing_sigma_ms = float(checkpoint_cfg.get('input_smoothing_sigma_bins', 2.0)) * 20.0
smoothing_kernel_size_ms = float(checkpoint_cfg.get('input_smoothing_kernel_size', 100)) * 20.0
input_transform_config = TimestepFlexibleInputTransformConfig(
    input_smoothing_sigma_ms=smoothing_sigma_ms,
    input_smoothing_kernel_size_ms=smoothing_kernel_size_ms,
    input_smoothing_threshold=float(checkpoint_cfg.get('input_smoothing_threshold', 0.01)),
    white_noise_sd=0.0,
    constant_offset_sd=0.0,
)
reference_patch_size_bins = int(checkpoint_cfg.get('patch_size', 14))
patch_size_ms = int(PATCH_SIZE_MS)
patch_stride_ms = int(PATCH_STRIDE_MS)
blank_index = int(problem['vocab']['blank_index'])

results = []
for active_bin_size_ms in (20, 40):
    stats = _load_stats_for_bin(problem, checkpoint_cfg, sample_dim, active_bin_size_ms)
    missing_rows = normalization_stats_missing_rows(stats, problem['val_rows'])
    if missing_rows:
        preview = ', '.join(missing_rows[:5])
        raise ValueError(
            f'Normalization stats for {active_bin_size_ms} ms bins do not cover the validation rows. '
            f'First missing examples: {preview}'
        )
    dataset = RebinnedSequenceDataset(
        problem['val_rows'],
        cache_root=Path(problem['cache_root']),
        stats=stats,
        feature_mode=str(problem['feature_mode']),
        boundary_key_mode=str(problem['boundary_key_mode']),
        dataset=str(problem['dataset']),
        active_bin_size_ms=int(active_bin_size_ms),
    )
    loader = DataLoader(
        dataset,
        batch_sampler=make_length_aware_batch_sampler(
            problem['val_rows'],
            batch_size=int(checkpoint_cfg.get('batch_size', BATCH_SIZE)),
            shuffle=False,
            seed=int(checkpoint_cfg.get('seed', 7)) + 1,
            bin_size_ms=int(active_bin_size_ms),
        ),
        **loader_kwargs(device),
    )
    metrics = _evaluate_willett_gru(
        model,
        loader,
        device,
        blank_index,
        input_transform_config,
        active_bin_size_ms=int(active_bin_size_ms),
        patch_size_ms=int(patch_size_ms),
        patch_stride_ms=int(patch_stride_ms),
        reference_patch_size_bins=int(reference_patch_size_bins),
    )
    results.append({
        'model': 'Willett GRU',
        'bin_size_ms': int(active_bin_size_ms),
        **metrics,
    })

if S5_SUMMARY_PATH.exists():
    s5_summary = json.loads(S5_SUMMARY_PATH.read_text())
    for active_bin_size_ms in (20, 40):
        results.append({
            'model': 'Timestep-flexible S5',
            'bin_size_ms': int(active_bin_size_ms),
            'val_ctc_bpphone': _extract_s5_metric(s5_summary, active_bin_size_ms, 'ctc_bpphone'),
            'val_phoneme_error_rate': _extract_s5_metric(s5_summary, active_bin_size_ms, 'phoneme_error_rate'),
        })

comparison_df = pd.DataFrame(results)
comparison_df = comparison_df.sort_values(['model', 'bin_size_ms']).reset_index(drop=True)
with pd.option_context('display.precision', 4):
    display(comparison_df[['model', 'bin_size_ms', 'val_ctc_bpphone', 'val_phoneme_error_rate']])

print('Saved Willett GRU best 20 ms reference from progress log:')
print(
    json.dumps(
        {
            'val_ctc_bpphone': GRU_SAVED_BEST_20MS_CTC,
            'val_phoneme_error_rate': GRU_SAVED_BEST_20MS_PER,
        },
        indent=2,
    )
)
# Out:
# Loaded canonical 20 ms split stats: /content/drive/MyDrive/utah_ssl/data/stats/split_feature_stats/raw/brain2text24/competition_train/tx_sbp/global_v1.pt
# Computing train-derived normalization stats for 40 ms bins...
#                   model  bin_size_ms  val_ctc_bpphone  val_phoneme_error_rate
# 0  Timestep-flexible S5           20           3.0730                  0.5893
# 1  Timestep-flexible S5           40           3.0789                  0.5907
# 2           Willett GRU           20           1.8476                  0.3724
# 3           Willett GRU           40           1.8561                  0.3735
# Saved Willett GRU best 20 ms reference from progress log:
# {
#   "val_ctc_bpphone": 1.8476455153996616,
#   "val_phoneme_error_rate": 0.3724146472360979
# }

# %% [markdown]
# ## Experiment Helpers
#
# Shared helpers for loading experiment summaries, rendering compact tables, and optionally appending notebook results back into the local `tests_and_results.md` note.

# %%
import json
from dataclasses import asdict
from pathlib import Path

import pandas as pd
from IPython.display import display

RESULTS_NOTE_PATH = REPO_DIR / 'experiments' / 'archive' / 'timestep_flexible_ssm' / 'tests_and_results.md'
WRITE_RESULTS_NOTE = False


def load_summary(path_like):
    path = Path(path_like)
    if not path.exists():
        raise FileNotFoundError(f'Missing summary file: {path}')
    return json.loads(path.read_text())


def load_progress_events(path_like):
    path = Path(path_like)
    if not path.exists():
        return []
    return [json.loads(line) for line in path.read_text().splitlines() if line.strip()]


def split_progress_segments(progress_rows):
    if not progress_rows:
        return []
    segments = []
    current = [progress_rows[0]]
    previous_step = int(progress_rows[0].get('step', 0))
    for row in progress_rows[1:]:
        step = int(row.get('step', 0))
        if step < previous_step:
            segments.append(current)
            current = [row]
        else:
            current.append(row)
        previous_step = step
    segments.append(current)
    return segments


def latest_val_event(progress_rows):
    for row in reversed(progress_rows):
        if str(row.get('event', '')).endswith('_val'):
            return row
    return None


def extract_supervised_bin_metrics(metrics_payload, bin_size_ms):
    nested = (metrics_payload or {}).get('metrics_by_bin_ms') or {}
    key = str(int(bin_size_ms))
    if key in nested:
        metrics = nested[key]
        return {
            'val_ctc_bpphone': float(metrics['val_ctc_bpphone']),
            'val_phoneme_error_rate': float(metrics['val_phoneme_error_rate']),
        }
    ctc_key = f'val_{int(bin_size_ms)}ms_ctc_bpphone'
    per_key = f'val_{int(bin_size_ms)}ms_phoneme_error_rate'
    if ctc_key in (metrics_payload or {}) and per_key in (metrics_payload or {}):
        return {
            'val_ctc_bpphone': float(metrics_payload[ctc_key]),
            'val_phoneme_error_rate': float(metrics_payload[per_key]),
        }
    raise KeyError(f'Could not find supervised metrics for {bin_size_ms} ms')


def resolve_run_metrics(run_dir, *, prefer_summary='auto', summary_metric_key='best_metrics'):
    run_dir = Path(run_dir)
    summary_path = run_dir / 'summary.json'
    progress_path = run_dir / 'progress.jsonl'
    progress_rows = load_progress_events(progress_path)
    segments = split_progress_segments(progress_rows)
    notes = []
    if len(segments) > 1:
        notes.append(f'progress log contains {len(segments)} step-reset segments')
    latest_segment = segments[-1] if segments else []
    latest_event = latest_val_event(latest_segment)
    summary_exists = summary_path.exists()
    progress_is_newer = summary_exists and progress_path.exists() and progress_path.stat().st_mtime > summary_path.stat().st_mtime
    use_summary = False
    if prefer_summary == 'auto':
        use_summary = summary_exists and (len(segments) > 1 or not progress_is_newer or latest_event is None)
    else:
        use_summary = bool(prefer_summary) and summary_exists
    if summary_exists and progress_is_newer and len(segments) <= 1 and latest_event is not None:
        notes.append('progress log is newer than summary.json; using latest validation from progress log')
    if use_summary:
        summary = load_summary(summary_path)
        metrics = dict(summary.get(summary_metric_key) or summary.get('metrics') or {})
        return {
            'source': 'summary.json',
            'run_dir': run_dir,
            'summary': summary,
            'metrics': metrics,
            'notes': '; '.join(notes) if notes else '',
            'segment_count': len(segments),
            'latest_progress_step': int(progress_rows[-1]['step']) if progress_rows else None,
        }
    if latest_event is None:
        raise FileNotFoundError(f'No summary.json and no validation event found under {run_dir}')
    return {
        'source': 'progress.jsonl',
        'run_dir': run_dir,
        'summary': None,
        'metrics': dict(latest_event),
        'notes': '; '.join(notes) if notes else '',
        'segment_count': len(segments),
        'latest_progress_step': int(latest_segment[-1]['step']) if latest_segment else None,
    }


def append_results_note(title, lines):
    if not WRITE_RESULTS_NOTE:
        print(f'Skipping note append for {title!r}; set WRITE_RESULTS_NOTE=True to enable.')
        return
    note = RESULTS_NOTE_PATH.read_text() if RESULTS_NOTE_PATH.exists() else ''
    block = ['\n', f'## {title}', ''] + [str(line) for line in lines] + ['']
    RESULTS_NOTE_PATH.write_text(note.rstrip() + '\n' + '\n'.join(block))
    print(f'Appended results to: {RESULTS_NOTE_PATH}')


def compact_metric_table(rows):
    frame = pd.DataFrame(rows)
    if frame.empty:
        return frame
    cols = [col for col in ['model', 'train_condition', 'eval_condition', 'bin_size_ms', 'horizon_ms', 'val_ctc_bpphone', 'val_phoneme_error_rate', 'infonce_loss'] if col in frame.columns]
    return frame[cols]

# %% [markdown]
# ## Experiment 1: Mixed-Bin Supervised Training
#
# Balanced supervised training on `20 ms` and `40 ms` views. The S5 consumes the active bin size directly, while the GRU consumes duplicated dense `20 ms` frames for the `40 ms` half of the mixture.

# %%
from experiments.archive.timestep_flexible_ssm.supervised_experiments import (
    SupervisedExperimentConfig,
    run_mixed_bin_gru,
    run_mixed_bin_s5,
)

MIXED_OUTPUT_ROOT = OUTPUT_ROOT / 'mixed_bin_supervised'
MIXED_OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)
MIXED_S5_RUN_NAME = 'mixed_bin_s5_tx_only_colab'
MIXED_GRU_RUN_NAME = 'mixed_bin_gru_tx_only_colab'
RUN_MIXED_EXPERIMENT = False

mixed_config = SupervisedExperimentConfig(
    cache_root=CACHE_ROOT,
    output_root=MIXED_OUTPUT_ROOT,
    feature_mode=FEATURE_MODE,
    dataset=DATASET,
    normalization_mode=NORMALIZATION_MODE,
    batch_size=BATCH_SIZE,
    max_steps=MAX_STEPS,
    learning_rate=LEARNING_RATE,
    min_learning_rate=MIN_LEARNING_RATE,
    adam_epsilon=ADAM_EPSILON,
    patch_size_ms=PATCH_SIZE_MS,
    patch_stride_ms=PATCH_STRIDE_MS,
    session_adapter_enabled=SESSION_ADAPTER,
    input_smoothing_sigma_ms=40.0,
    input_smoothing_kernel_size_ms=2000.0,
    input_smoothing_threshold=0.01,
    mixed_bin_sizes_ms=(20, 40),
)

if RUN_MIXED_EXPERIMENT:
    mixed_s5_summary = run_mixed_bin_s5(
        SupervisedExperimentConfig(**{**asdict(mixed_config), 'run_name': MIXED_S5_RUN_NAME})
    )
    mixed_gru_summary = run_mixed_bin_gru(
        SupervisedExperimentConfig(
            **{
                **asdict(mixed_config),
                'run_name': MIXED_GRU_RUN_NAME,
                'learning_rate': 1e-2,
                'min_learning_rate': 1e-4,
                'adam_epsilon': 1e-1,
            }
        )
    )
    print(json.dumps({'mixed_s5': mixed_s5_summary['summary_path'], 'mixed_gru': mixed_gru_summary['summary_path']}, indent=2))
else:
    print('Set RUN_MIXED_EXPERIMENT=True to launch the mixed-bin training runs.')
# Out:
# Set RUN_MIXED_EXPERIMENT=True to launch the mixed-bin training runs.

# %%
mixed_s5_summary_path = MIXED_OUTPUT_ROOT / MIXED_S5_RUN_NAME / 'summary.json'
mixed_gru_summary_path = MIXED_OUTPUT_ROOT / MIXED_GRU_RUN_NAME / 'summary.json'

rows = []
artifact_rows = []
if summary_path.exists():
    baseline_s5 = resolve_run_metrics(RUN_DIR)
    baseline_20 = extract_supervised_bin_metrics(baseline_s5['metrics'], 20)
    baseline_40 = extract_supervised_bin_metrics(baseline_s5['metrics'], 40)
    rows.extend([
        {
            'model': 'Baseline S5',
            'train_condition': '20 ms only',
            'eval_condition': '20 ms',
            'bin_size_ms': 20,
            'val_ctc_bpphone': baseline_20['val_ctc_bpphone'],
            'val_phoneme_error_rate': baseline_20['val_phoneme_error_rate'],
        },
        {
            'model': 'Baseline S5',
            'train_condition': '20 ms only',
            'eval_condition': '40 ms',
            'bin_size_ms': 40,
            'val_ctc_bpphone': baseline_40['val_ctc_bpphone'],
            'val_phoneme_error_rate': baseline_40['val_phoneme_error_rate'],
        },
    ])
    artifact_rows.append({'model': 'Baseline S5', 'metric_source': baseline_s5['source'], 'progress_segments': baseline_s5['segment_count'], 'latest_progress_step': baseline_s5['latest_progress_step'], 'notes': baseline_s5['notes']})
if mixed_s5_summary_path.exists():
    mixed_s5 = resolve_run_metrics(MIXED_OUTPUT_ROOT / MIXED_S5_RUN_NAME)
    mixed_s5_20 = extract_supervised_bin_metrics(mixed_s5['metrics'], 20)
    mixed_s5_40 = extract_supervised_bin_metrics(mixed_s5['metrics'], 40)
    rows.extend([
        {
            'model': 'Mixed S5',
            'train_condition': '50/50 20 ms + 40 ms',
            'eval_condition': '20 ms',
            'bin_size_ms': 20,
            'val_ctc_bpphone': mixed_s5_20['val_ctc_bpphone'],
            'val_phoneme_error_rate': mixed_s5_20['val_phoneme_error_rate'],
        },
        {
            'model': 'Mixed S5',
            'train_condition': '50/50 20 ms + 40 ms',
            'eval_condition': '40 ms',
            'bin_size_ms': 40,
            'val_ctc_bpphone': mixed_s5_40['val_ctc_bpphone'],
            'val_phoneme_error_rate': mixed_s5_40['val_phoneme_error_rate'],
        },
    ])
    artifact_rows.append({'model': 'Mixed S5', 'metric_source': mixed_s5['source'], 'progress_segments': mixed_s5['segment_count'], 'latest_progress_step': mixed_s5['latest_progress_step'], 'notes': mixed_s5['notes']})
if mixed_gru_summary_path.exists():
    mixed_gru = resolve_run_metrics(MIXED_OUTPUT_ROOT / MIXED_GRU_RUN_NAME)
    mixed_gru_20 = extract_supervised_bin_metrics(mixed_gru['metrics'], 20)
    mixed_gru_40 = extract_supervised_bin_metrics(mixed_gru['metrics'], 40)
    rows.extend([
        {
            'model': 'Mixed GRU',
            'train_condition': '50/50 20 ms + 40 ms duplicated',
            'eval_condition': '20 ms',
            'bin_size_ms': 20,
            'val_ctc_bpphone': mixed_gru_20['val_ctc_bpphone'],
            'val_phoneme_error_rate': mixed_gru_20['val_phoneme_error_rate'],
        },
        {
            'model': 'Mixed GRU',
            'train_condition': '50/50 20 ms + 40 ms duplicated',
            'eval_condition': '40 ms',
            'bin_size_ms': 40,
            'val_ctc_bpphone': mixed_gru_40['val_ctc_bpphone'],
            'val_phoneme_error_rate': mixed_gru_40['val_phoneme_error_rate'],
        },
    ])
    artifact_rows.append({'model': 'Mixed GRU', 'metric_source': mixed_gru['source'], 'progress_segments': mixed_gru['segment_count'], 'latest_progress_step': mixed_gru['latest_progress_step'], 'notes': mixed_gru['notes']})
frame = compact_metric_table(rows)
with pd.option_context('display.precision', 4):
    display(frame)
if artifact_rows:
    display(pd.DataFrame(artifact_rows))
append_results_note('Mixed-Bin Supervised Results', frame.to_markdown(index=False).splitlines())
# Out:
#          model train_condition eval_condition  bin_size_ms  val_ctc_bpphone  \
# 0  Baseline S5      20 ms only          20 ms           20           3.0730
# 1  Baseline S5      20 ms only          40 ms           40           3.0789
#
#    val_phoneme_error_rate
# 0                  0.5893
# 1                  0.5907
# Skipping note append for 'Mixed-Bin Supervised Results'; set WRITE_RESULTS_NOTE=True to enable.

# %% [markdown]
# ## Experiment 2: Missing-Bin Supervised Training
#
# Random Bernoulli dropping with `p = 0.25`. The S5 consumes the irregular sequence with timestep deltas, while the GRU trains on interpolated dense inputs and evaluates with carry-forward reconstruction.

# %%
from experiments.archive.timestep_flexible_ssm.supervised_experiments import (
    SupervisedExperimentConfig,
    run_missing_bin_gru,
    run_missing_bin_s5,
)

MISSING_OUTPUT_ROOT = OUTPUT_ROOT / 'missing_bin_supervised'
MISSING_OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)
MISSING_S5_RUN_NAME = 'missing_bin_s5_tx_only_colab'
MISSING_GRU_RUN_NAME = 'missing_bin_gru_tx_only_colab'
RUN_MISSING_EXPERIMENT = False

missing_config = SupervisedExperimentConfig(
    cache_root=CACHE_ROOT,
    output_root=MISSING_OUTPUT_ROOT,
    feature_mode=FEATURE_MODE,
    dataset=DATASET,
    normalization_mode=NORMALIZATION_MODE,
    batch_size=BATCH_SIZE,
    max_steps=MAX_STEPS,
    learning_rate=LEARNING_RATE,
    min_learning_rate=MIN_LEARNING_RATE,
    adam_epsilon=ADAM_EPSILON,
    patch_size_ms=PATCH_SIZE_MS,
    patch_stride_ms=PATCH_STRIDE_MS,
    session_adapter_enabled=SESSION_ADAPTER,
    input_smoothing_sigma_ms=40.0,
    input_smoothing_kernel_size_ms=2000.0,
    input_smoothing_threshold=0.01,
    missing_drop_probability=0.25,
    train_mask_seed=101,
    val_mask_seed=202,
)

if RUN_MISSING_EXPERIMENT:
    missing_s5_summary = run_missing_bin_s5(
        SupervisedExperimentConfig(**{**asdict(missing_config), 'run_name': MISSING_S5_RUN_NAME})
    )
    missing_gru_summary = run_missing_bin_gru(
        SupervisedExperimentConfig(
            **{
                **asdict(missing_config),
                'run_name': MISSING_GRU_RUN_NAME,
                'learning_rate': 1e-2,
                'min_learning_rate': 1e-4,
                'adam_epsilon': 1e-1,
            }
        )
    )
    print(json.dumps({'missing_s5': missing_s5_summary['summary_path'], 'missing_gru': missing_gru_summary['summary_path']}, indent=2))
else:
    print('Set RUN_MISSING_EXPERIMENT=True to launch the missing-bin training runs.')
# Out:
# Set RUN_MISSING_EXPERIMENT=True to launch the missing-bin training runs.

# %%
missing_s5_summary_path = MISSING_OUTPUT_ROOT / MISSING_S5_RUN_NAME / 'summary.json'
missing_gru_summary_path = MISSING_OUTPUT_ROOT / MISSING_GRU_RUN_NAME / 'summary.json'

rows = []
if missing_s5_summary_path.exists():
    missing_s5 = load_summary(missing_s5_summary_path)
    rows.append({
        'model': 'Missing-bin S5',
        'train_condition': 'Bernoulli drop p=0.25',
        'eval_condition': 'Bernoulli drop p=0.25',
        'val_ctc_bpphone': missing_s5['best_metrics']['val_ctc_bpphone'],
        'val_phoneme_error_rate': missing_s5['best_metrics']['val_phoneme_error_rate'],
    })
if missing_gru_summary_path.exists():
    missing_gru = load_summary(missing_gru_summary_path)
    rows.append({
        'model': 'Missing-bin GRU',
        'train_condition': 'Interpolation train, carry-forward eval',
        'eval_condition': 'Bernoulli drop p=0.25',
        'val_ctc_bpphone': missing_gru['best_metrics']['val_ctc_bpphone'],
        'val_phoneme_error_rate': missing_gru['best_metrics']['val_phoneme_error_rate'],
    })
frame = compact_metric_table(rows)
with pd.option_context('display.precision', 4):
    display(frame)
append_results_note('Missing-Bin Supervised Results', frame.to_markdown(index=False).splitlines())
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# Skipping note append for 'Missing-Bin Supervised Results'; set WRITE_RESULTS_NOTE=True to enable.

# %% [markdown]
# ## Experiment 3: Future-Bin InfoNCE Runs
#
# Separate future-prediction runs from canonical `20 ms` data, using normalized future frame bins as the positive targets at `20, 40, 60, 80, 100 ms` horizons.

# %%
from experiments.archive.timestep_flexible_ssm.future_infonce import FutureInfoNCEConfig, run_future_infonce

FUTURE_OUTPUT_ROOT = OUTPUT_ROOT / 'future_infonce'
FUTURE_OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)
FUTURE_S5_RUN_NAME = 'future_infonce_s5_tx_only_colab'
FUTURE_GRU_RUN_NAME = 'future_infonce_gru_tx_only_colab'
RUN_FUTURE_EXPERIMENT = False

future_config = FutureInfoNCEConfig(
    cache_root=CACHE_ROOT,
    output_root=FUTURE_OUTPUT_ROOT,
    feature_mode=FEATURE_MODE,
    dataset=DATASET,
    normalization_mode=NORMALIZATION_MODE,
    batch_size=BATCH_SIZE,
    max_steps=MAX_STEPS,
    learning_rate=LEARNING_RATE,
    min_learning_rate=MIN_LEARNING_RATE,
    adam_epsilon=ADAM_EPSILON,
    patch_size_ms=PATCH_SIZE_MS,
    patch_stride_ms=PATCH_STRIDE_MS,
    session_adapter_enabled=SESSION_ADAPTER,
    input_smoothing_sigma_ms=40.0,
    input_smoothing_kernel_size_ms=2000.0,
    input_smoothing_threshold=0.01,
    horizons_ms=(20, 40, 60, 80, 100),
    projection_dim=128,
)

if RUN_FUTURE_EXPERIMENT:
    future_s5_summary = run_future_infonce(
        FutureInfoNCEConfig(**{**asdict(future_config), 'run_name': FUTURE_S5_RUN_NAME, 'model_family': 's5'})
    )
    future_gru_summary = run_future_infonce(
        FutureInfoNCEConfig(
            **{
                **asdict(future_config),
                'run_name': FUTURE_GRU_RUN_NAME,
                'model_family': 'gru',
                'learning_rate': 1e-2,
                'min_learning_rate': 1e-4,
                'adam_epsilon': 1e-1,
            }
        )
    )
    print(json.dumps({'future_s5': future_s5_summary['summary_path'], 'future_gru': future_gru_summary['summary_path']}, indent=2))
else:
    print('Set RUN_FUTURE_EXPERIMENT=True to launch the future InfoNCE runs.')
# Out:
# Set RUN_FUTURE_EXPERIMENT=True to launch the future InfoNCE runs.

# %%
future_s5_summary_path = FUTURE_OUTPUT_ROOT / FUTURE_S5_RUN_NAME / 'summary.json'
future_gru_summary_path = FUTURE_OUTPUT_ROOT / FUTURE_GRU_RUN_NAME / 'summary.json'

frames = []
for model_name, path in [('Future S5', future_s5_summary_path), ('Future GRU', future_gru_summary_path)]:
    if not path.exists():
        continue
    summary = load_summary(path)
    metrics = dict(summary.get('metrics') or {})
    for key, value in metrics.items():
        if key.startswith('h') and key.endswith('_infonce_loss'):
            horizon_ms = int(key[1:].split('_', 1)[0])
            frames.append({
                'model': model_name,
                'horizon_ms': horizon_ms,
                'infonce_loss': float(value),
            })
frame = compact_metric_table(frames).sort_values(['model', 'horizon_ms']) if frames else pd.DataFrame()
with pd.option_context('display.precision', 4):
    display(frame)
append_results_note('Future InfoNCE Results', frame.to_markdown(index=False).splitlines() if not frame.empty else ['No future summaries yet.'])
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# Skipping note append for 'Future InfoNCE Results'; set WRITE_RESULTS_NOTE=True to enable.

# %% [markdown]
# ## Final Comparison
#
# Aggregate any completed experiment summaries into one notebook view. This is intentionally lightweight so you can rerun it after any subset of experiments completes.

# %%
summary_rows = []

candidate_paths = [
    ('Baseline S5', summary_path),
    ('Mixed S5', MIXED_OUTPUT_ROOT / MIXED_S5_RUN_NAME / 'summary.json'),
    ('Mixed GRU', MIXED_OUTPUT_ROOT / MIXED_GRU_RUN_NAME / 'summary.json'),
    ('Missing-bin S5', MISSING_OUTPUT_ROOT / MISSING_S5_RUN_NAME / 'summary.json'),
    ('Missing-bin GRU', MISSING_OUTPUT_ROOT / MISSING_GRU_RUN_NAME / 'summary.json'),
    ('Future S5', FUTURE_OUTPUT_ROOT / FUTURE_S5_RUN_NAME / 'summary.json'),
    ('Future GRU', FUTURE_OUTPUT_ROOT / FUTURE_GRU_RUN_NAME / 'summary.json'),
]

for label, path in candidate_paths:
    if not Path(path).exists():
        continue
    summary = load_summary(path)
    metrics = dict(summary.get('best_metrics') or summary.get('metrics') or {})
    row = {
        'model': label,
        'artifact_path': str(path),
    }
    for key in ['val_20ms_ctc_bpphone', 'val_40ms_ctc_bpphone', 'val_20ms_phoneme_error_rate', 'val_40ms_phoneme_error_rate', 'mean_infonce_loss']:
        if key in metrics:
            row[key] = metrics[key]
    summary_rows.append(row)

summary_frame = pd.DataFrame(summary_rows)
with pd.option_context('display.precision', 4):
    display(summary_frame)
print('Results note path:', RESULTS_NOTE_PATH)
# Out:
#          model                                      artifact_path  \
# 0  Baseline S5  /content/drive/MyDrive/utah_ssl/outputs/timest...
#
#    val_20ms_ctc_bpphone  val_40ms_ctc_bpphone  val_20ms_phoneme_error_rate  \
# 0                 3.073                3.0789                       0.5893
#
#    val_40ms_phoneme_error_rate
# 0                       0.5907
# Results note path: /content/utah-ssl/experiments/archive/timestep_flexible_ssm/results/README.md

# %%
from google.colab import runtime
runtime.unassign()
